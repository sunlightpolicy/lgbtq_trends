# %% [markdown]
# # Sunlight Foundation | LGBTQ Trend Report
#
# 1. [URL set](#section_1)
# 2. [Content Analysis](#section_2)
#   1. Defining terms
#   2. Getting counts
#   3. Analyzing results
# 3. [Sentiment Analysis](#section_3)
# 4. [Case study: HUD](#section_4)

# %%
import scripts.sentiment_analysis as ta
import scripts.get_content as gc
import scripts.analysis as a
import pandas as pd
import numpy as np
import nltk
import csv
import os

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# <a id='section_1'></a>
# ## 1. Constructing URL set

# %% [markdown]
# We got the URLs that result from searches on usa.gov's search engine on a list of terms (term_search). Then, we combined them with some previosuly wip-identified urls and then performed a visual inspection to remove any urls that our code was not able to capture (13 urls out of 295 urls). The final output from this inspection for the next section of this analysis is named links_final.csv (in the inputs folder).

# %%
term_search = ['lgbtq', 'lgbt', 'transgender', 'gay', 'lesbian', 'bisexual', 'queer']
usagov_search = gc.gen_usagovsearch(term_search, 5)
# this function also saves the usagov search pages in a csv in the inputs folder
potential_urls, exceptions = gc.get_hrefs(usagov_search)
# uncomment following two lines to see ouput in csv
#potential_df = pd.DataFrame(list(potential_urls))
#potential_df.to_csv('inputs/potential_urls.csv')

# %%
# we use the urls that were previously identified by wip
wip_urls = gc.read_csv('inputs/wip_identified.csv')
wip_urls = [url[0] for url in wip_urls]
wip_urls = set(wip_urls)
final_links = list(wip_urls.union(potential_urls))
df_links = pd.DataFrame(final_links)
df_links.to_csv('inputs/final_urls_for_visual_check.csv')

# %% [markdown]
# <a id='section_2'></a>
# ## 2. Content Analysis

# %% [markdown]
# #### A. Term definition
#
# These terms were collected from:
# 1. https://www.edi.nih.gov/people/sep/lgbti/safezone/terminology
# 2. https://www.nap.edu/read/13128/chapter/12
# 3. https://www.lgbthealtheducation.org/wp-content/uploads/LGBT-Glossary_March2016.pdf

# %%
one_word_terms = [
                 'agender',
                 'ally',
                 'aromantic',
                 'asexual',
                 'biphobia',
                 'bisexual',
                 'cisgender',
                 'gay',
                 'gender',
                 'genderqueer',
                 'glbt',
                 'heteronormativity',
                 'heterosexism',
                 'heterosexual',
                 'hiv',
                 'homophobia',
                 'intersex',
                 'lesbian',
                 'lgb',
                 'lgbt',
                 'lgbtq',
                 'msm',
                 'outing',
                 'pangender',
                 'pansexual',
                 'polyamorous',
                 'queer',
                 'questioning',
                 'serostatus',
                 'sex',
                 'straight',
                 'transexual',
                 'transgender',
                 'transgenderist',
                 'transsexual',
                 'wsw'
                 ]
two_word_terms =  [
                 ['assigned', 'sex'],
                 ['drag', 'queen'],
                 ['drag', 'king'],
                 ['gender', 'expression'],
                 ['gender', 'identity'],
                 ['gender', 'nonconforming'],
                 ['gender', 'role'],
                 ['gender', 'minority'],
                 ['gender', 'dysphoria'],
                 ['gender', 'fluid'],
                 ['gender', 'binary'],
                 ['hormone', 'therapy'],
                 ['same-sex', 'marriage'],
                 ['same-sex', 'relationship'],
                 ['same-sex', 'couple'],
                 ['same-sex', 'couples'],
                 ['same-sex', 'attraction'],
                 ['sex', 'minority'],
                 ['sex', 'reassignment'],
                 ['sexual', 'orientation'],
                 ['two', 'spirit']]
# two_word_terms.sort(key=lambda x: x[0])

# %% [markdown]
# #### B. Getting counts
#
# This function gets the total number of times that each term appeared in the visible body of text in the set of analyzed urls before President Trump's inauguration and two and a half years into his administration.

# %%
terms = one_word_terms + two_word_terms
control_terms = ['heterosexual', 'straight']
dates_pre = [2013, 1, 20, 2017, 1, 19]
dates_post = [2017, 1, 20, 2019, 8, 8]
output_name = 'counts_final'
gc.get_output('inputs/links_final.csv', output_name, terms, dates_pre, dates_post, store_text=True)
# Out:
# HBox(children=(IntProgress(value=0, description='progress: ', max=282, style=ProgressStyle(description_width='…

# %% [markdown]
# #### C. Analyzing results

# %%
multi_word_terms = two_word_terms[:]
department_path = 'inputs/departments_final.csv'
df_pre_merged, df_post_merged, col_names = a.get_final_df(department_path, multi_word_terms, one_word_terms, output_name)
inconsistencies = [23, 90, 146, 273]
df_pre_merged = df_pre_merged[~df_pre_merged.id.isin(inconsistencies)]
df_post_merged = df_post_merged[~df_post_merged.id.isin(inconsistencies)]
rel_changes, rel_pre, rel_post = a.get_changes(df_pre_merged, df_post_merged, 'id', col_names, 'ttal', pctg=True)
abs_changes = a.get_changes(df_pre_merged, df_post_merged, 'id', col_names, 'ttal', pctg=False)
# uncomment to check relative frequencies
#rel_pre.sort_values()
#rel_post.sort_values()
# Out:
# The relative number of terms changed 1.05 %, from 0.051 to 0.052
# The absolute number of terms changed 1.30 %, from 8386 to 8495

# %%
a.display_side_by_side(rel_changes, abs_changes)
# Out:
# <table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>term</th>
#       <th>change</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>same-sex couple</td>
#       <td>-100.00</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>same-sex relationship</td>
#       <td>-100.00</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>queer</td>
#       <td>-11.61</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>msm</td>
#       <td>-8.92</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>questioning</td>
#       <td>-8.12</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>glbt</td>
#       <td>-6.11</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>intersex</td>
#       <td>-5.49</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>lesbian</td>
#       <td>-3.75</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>gay</td>
#       <td>-2.73</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>sex</td>
#       <td>-2.66</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>lgbt</td>
#       <td>-2.27</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>bisexual</td>
#       <td>-1.93</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>gender role</td>
#       <td>-0.24</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>wsw</td>
#       <td>-0.24</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>two spirit</td>
#       <td>-0.24</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>genderqueer</td>
#       <td>-0.24</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>sex reassignment</td>
#       <td>-0.24</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>outing</td>
#       <td>-0.24</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>pansexual</td>
#       <td>-0.24</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>polyamorous</td>
#       <td>-0.24</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>heterosexism</td>
#       <td>-0.24</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>biphobia</td>
#       <td>-0.24</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>transsexual</td>
#       <td>-0.24</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>assigned sex</td>
#       <td>-0.24</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>same-sex attraction</td>
#       <td>-0.24</td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td>gender identity</td>
#       <td>0.47</td>
#     </tr>
#     <tr>
#       <th>26</th>
#       <td>sexual orientation</td>
#       <td>1.71</td>
#     </tr>
#     <tr>
#       <th>27</th>
#       <td>transgender</td>
#       <td>2.11</td>
#     </tr>
#     <tr>
#       <th>28</th>
#       <td>lgbtq</td>
#       <td>2.60</td>
#     </tr>
#     <tr>
#       <th>29</th>
#       <td>same-sex couples</td>
#       <td>2.98</td>
#     </tr>
#     <tr>
#       <th>30</th>
#       <td>straight</td>
#       <td>3.32</td>
#     </tr>
#     <tr>
#       <th>31</th>
#       <td>homophobia</td>
#       <td>3.75</td>
#     </tr>
#     <tr>
#       <th>32</th>
#       <td>gender dysphoria</td>
#       <td>5.46</td>
#     </tr>
#     <tr>
#       <th>33</th>
#       <td>same-sex marriage</td>
#       <td>5.63</td>
#     </tr>
#     <tr>
#       <th>34</th>
#       <td>gender</td>
#       <td>5.94</td>
#     </tr>
#     <tr>
#       <th>35</th>
#       <td>heterosexual</td>
#       <td>7.37</td>
#     </tr>
#     <tr>
#       <th>36</th>
#       <td>gender nonconforming</td>
#       <td>9.26</td>
#     </tr>
#     <tr>
#       <th>37</th>
#       <td>gender expression</td>
#       <td>9.73</td>
#     </tr>
#     <tr>
#       <th>38</th>
#       <td>hiv</td>
#       <td>13.51</td>
#     </tr>
#     <tr>
#       <th>39</th>
#       <td>lgb</td>
#       <td>15.51</td>
#     </tr>
#     <tr>
#       <th>40</th>
#       <td>ally</td>
#       <td>33.01</td>
#     </tr>
#     <tr>
#       <th>41</th>
#       <td>gender minority</td>
#       <td>58.44</td>
#     </tr>
#     <tr>
#       <th>42</th>
#       <td>hormone therapy</td>
#       <td>66.26</td>
#     </tr>
#     <tr>
#       <th>43</th>
#       <td>cisgender</td>
#       <td>inf</td>
#     </tr>
#   </tbody>
# </table style="display:inline"><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>term</th>
#       <th>change</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>gay</td>
#       <td>-24.00</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>lesbian</td>
#       <td>-22.00</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>lgbt</td>
#       <td>-21.00</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>sex</td>
#       <td>-15.00</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>bisexual</td>
#       <td>-13.00</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>queer</td>
#       <td>-9.00</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>msm</td>
#       <td>-8.00</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>questioning</td>
#       <td>-6.00</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>glbt</td>
#       <td>-3.00</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>same-sex couple</td>
#       <td>-1.00</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>same-sex relationship</td>
#       <td>-1.00</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>intersex</td>
#       <td>-1.00</td>
#     </tr>
#     <tr>
#       <th>38</th>
#       <td>same-sex couples</td>
#       <td>1.00</td>
#     </tr>
#     <tr>
#       <th>39</th>
#       <td>straight</td>
#       <td>1.00</td>
#     </tr>
#     <tr>
#       <th>40</th>
#       <td>same-sex marriage</td>
#       <td>1.00</td>
#     </tr>
#     <tr>
#       <th>41</th>
#       <td>homophobia</td>
#       <td>1.00</td>
#     </tr>
#     <tr>
#       <th>42</th>
#       <td>gender dysphoria</td>
#       <td>2.00</td>
#     </tr>
#     <tr>
#       <th>43</th>
#       <td>gender nonconforming</td>
#       <td>2.00</td>
#     </tr>
#     <tr>
#       <th>44</th>
#       <td>gender identity</td>
#       <td>2.00</td>
#     </tr>
#     <tr>
#       <th>45</th>
#       <td>gender expression</td>
#       <td>2.00</td>
#     </tr>
#     <tr>
#       <th>46</th>
#       <td>ally</td>
#       <td>2.00</td>
#     </tr>
#     <tr>
#       <th>47</th>
#       <td>hormone therapy</td>
#       <td>4.00</td>
#     </tr>
#     <tr>
#       <th>48</th>
#       <td>cisgender</td>
#       <td>6.00</td>
#     </tr>
#     <tr>
#       <th>49</th>
#       <td>sexual orientation</td>
#       <td>7.00</td>
#     </tr>
#     <tr>
#       <th>50</th>
#       <td>heterosexual</td>
#       <td>10.00</td>
#     </tr>
#     <tr>
#       <th>51</th>
#       <td>gender minority</td>
#       <td>10.00</td>
#     </tr>
#     <tr>
#       <th>52</th>
#       <td>lgbtq</td>
#       <td>13.00</td>
#     </tr>
#     <tr>
#       <th>53</th>
#       <td>lgb</td>
#       <td>18.00</td>
#     </tr>
#     <tr>
#       <th>54</th>
#       <td>transgender</td>
#       <td>24.00</td>
#     </tr>
#     <tr>
#       <th>55</th>
#       <td>gender</td>
#       <td>37.00</td>
#     </tr>
#     <tr>
#       <th>56</th>
#       <td>hiv</td>
#       <td>90.00</td>
#     </tr>
#   </tbody>
# </table style="display:inline">

# %% [markdown]
# *Absolute changes*
#
# The five terms that most increased their absolute presence were “HIV”, “LGBTQ”, “gender”, “transgender” and “LGB”. The five terms that most decreased their absolute presence are: “gay”, “LGBT”, “lesbian”, “sex” and “bisexual” (Figure 2). The rise in the use of more inclusive terms (for example, “LGBTQ” as an umbrella term for “lesbian”, “gay”, “bisexual”, “LGBT”). On aggregate, there seems to be a move towards an increased use of umbrella terms like “LGBTQ” as well as an increase in the use of “transgender”. Assessing whether this is actually a positive change that has contributed to the offer of more inclusive services or not is beyond the scope of this report.

# %%
a.plot_bars(abs_changes, 'term', 'change')

# %% [markdown]
# *Relative changes*
#
# To contextualize the observed relative changes, it must be noted that no term represents more than 0.65% of all words across the analyzed websites. Therefore, small absolute increases result in large relative increases. The five terms that most increased their relative presence were “cisgender”, “hormone therapy”, “gender minority”, “ally” and “LGB”. The five terms that saw the biggest decrease in their relative presence were “same-sex couple”, “same-sex relationship”, “queer”, “MSM” and “questioning”. None of the terms with a top 5 increase in absolute terms saw a top 5 increase in relative terms.
#
#
# Note. The term cisgender did not appear before, hence the change is infinity

# %%
a.plot_bars(rel_changes, 'term', 'change')

# %% [markdown]
# *Changes by Department*

# %%
df = a.plot_dpt_changes(df_pre_merged, df_post_merged, col_names, control_terms)

# %% [markdown]
# *Absolute Changes in Terms by Department*
#
# Plots of the absolute changes by department with most changes.

# %%
department_list = ['U.S. Department of Health and Human Services', 'U.S. Department of the Interior',
                   'U.S. Department of Labor', 'U.S. Department of Housing and Urban Development ',
                   'U.S. Department of Education', 'Interagency Working Group',
                   'U.S. Department of Veterans Affairs',
                   'U.S. Department of Justice',
                   'Peace Corps', 'U.S. Social Security Administration']
a.plot_changes_dept(df_pre_merged, df_post_merged, col_names, department_list)
# Out:
# U.S. Department of Health and Human Services
# The absolute number of terms changed 4.37 %, from 5608 to 5853
# U.S. Department of the Interior
# The absolute number of terms changed -9.50 %, from 421 to 381
# U.S. Department of Labor
# The absolute number of terms changed -20.30 %, from 202 to 161
# U.S. Department of Housing and Urban Development
# The absolute number of terms changed -11.21 %, from 116 to 103
# U.S. Department of Education
# The absolute number of terms changed -57.14 %, from 21 to 9
# Interagency Working Group
# The absolute number of terms changed -7.86 %, from 598 to 551
# U.S. Department of Veterans Affairs
# The absolute number of terms changed 3.36 %, from 536 to 554
# U.S. Department of Justice
# The absolute number of terms changed -0.36 %, from 825 to 822
# Peace Corps
# The absolute number of terms changed -3.12 %, from 32 to 31
# U.S. Social Security Administration
# The absolute number of terms changed 25.00 %, from 12 to 15

# %% [markdown]
# <a id='section_3'></a>
# ## 3. Tone Analysis
#
# In this section I perform an analysis on how the tone of the content across websites has changed over time. To do so, I use the [pysentiment](https://github.com/hanzhichao2000/pysentiment) package, which uses the [Harvard IV-4](http://www.wjh.harvard.edu/~inquirer/homecat.htm) sentiment dictionary for general content analysis. The Harvard IV-4 dictionary provides a better suited alternative than other more widely used dictionaries that are tailored for social-media sentiment analysis. I use the default library's tokenizer, which converts alphabetic text to lowercase, stems it using nltk.PorterStemmer and excludes words in [predefined stoplists](https://github.com/hanzhichao2000/pysentiment/tree/master/pysentiment/static) (currencies, dates and numbers, geographic, names and other generic words). Then, I calculate the polarity and subjectivity scores of each website at both points in time (ie. pre and post) as:
#
# * polarity(website) = (&Sigma; positive tokens - &Sigma; negative tokens) / (&Sigma; positive tokens + &Sigma; negative tokens)
#
# * subjectivity(website) = (&Sigma; positive tokens - &Sigma; negative tokens) / (&Sigma; all tokens)
#
# For the purpose of this analysis, subjectivity is more important, as I'm trying to detect any signficant changes in the way that information is conveyed across Federal government websites. The interpretation of polarity is largely restricted to each website, as the definition of what consitutes positive or negative language is not clearly captured by the dictionary that I'm using.

# %%
data_pre = ta.get_tone(df_pre_merged)
ta_df_pre = pd.DataFrame.from_dict(data_pre)
ta_df_pre.polarity.mean(), ta_df_pre.subjectivity.mean()
#ta_df_pre.sort_values(by='subjectivity', ascending=False)
# Out:
# (0.4792497881613576, 0.2851123444981216)

# %%
data_post = ta.get_tone(df_post_merged)
ta_df_post = pd.DataFrame.from_dict(data_post)
ta_df_post.polarity.mean(), ta_df_post.subjectivity.mean()
#ta_df_post.sort_values(by='subjectivity', ascending=False)
# Out:
# (0.48474776772272904, 0.29204616098675057)

# %%
normality_subj = a.plot_normal(ta_df_pre, ta_df_post, 'subjectivity')
# Out:
# With a p-value of 1.0185000412499257e-11, we reject the null hypothesis that the data was drawn from a normal distribution

# %%
normality_pol = a.plot_normal(ta_df_pre, ta_df_post, 'polarity')
# Out:
# With a p-value of 2.1961794362257425e-13, we reject the null hypothesis that the data was drawn from a normal distribution

# %% [markdown]
# Since the pre post differences in polarity and subjectivity do not seem to be normally distributed (ie. they are skewed), we use the Wilcoxon test to test for the signficance of the results at the 10% level.

# %%
significance = 5
a.test_significance(ta_df_pre, ta_df_post, 'subjectivity', significance, normality_subj)
a.test_significance(ta_df_pre, ta_df_post, 'polarity', significance, normality_pol)
# Out:
# The change in subjectivity is statistically significant at the 5 %
# The change in polarity is not statistically significant at the 5 %

# %%
df = a.plot_boxplot(ta_df_pre, ta_df_post)

# %% [markdown]
# Some sanity checking functions to check for any potential text discrepancies
#
# Note. Avoid using iterrows!

# %%
for index, row in df_pre_merged.iterrows():
    if len(row.text) < 5:
        print(row.id, row.url)
        print(row.text)
        print('*******')

# %%
for index, row in df_post_merged.iterrows():
    if len(row.text) < 5:
        print(row.id, row.url)
        print(row.text)
        print('*******')

# %% [markdown]
# <a id='section_4'></a>
# ## 4. Department Case Analysis: HUD
#
# We got all the available links from hud.gov, hudexchange.info and huduser

# %%
driver_path = os.getcwd() + '/scripts/chromedriver'
# Out:
# '/Users/sunlightfellow/Google Drive/lgbtq_trends/src/scripts/chromedriver'

# %% [markdown]
# hud.gov

# %%
wayback_url = 'https://web.archive.org/web/*/www.hud.gov/*'
browser = gc.open_chrome(wayback_url, driver_path)

# %%
hud = gc.get_urls(browser, 'Jan 20, 2013', 'Jan 19, 2017', "src/hud/hud_links.csv")
# Out:
# HBox(children=(IntProgress(value=0, description='progress: ', max=1619, style=ProgressStyle(description_width=…
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//a[@class="paginate_button next" and @id="resultsUrl_next"]"}
#   (Session info: chrome=76.0.3809.100)

# %% [markdown]
# hudexchange.info

# %%
wayback_url = 'https://web.archive.org/web/*/www.hudexchange.info/*'
browser = gc.open_chrome(wayback_url, driver_path)

# %%
hud_exchange = gc.get_urls(browser, 'Jan 20, 2013', 'Jan 19, 2017', "hud_exchange_links.csv")
# Out:
# HBox(children=(IntProgress(value=0, description='progress: ', max=2000, style=ProgressStyle(description_width=…

# %%
stored_copy = lst + hud_exchange
len('https://web.archive.org/web/*/')
for row in stored_copy:
    row[0] = row[0][30:]
# Out:
# [['http://hud.gov:80/budgetsummary2011/index.cfm',
#   datetime.datetime(2010, 3, 8, 0, 0),
#   datetime.datetime(2015, 9, 8, 0, 0)],
#  ['http://hud.gov:80/data',
#   datetime.datetime(2014, 10, 24, 0, 0),
#   datetime.datetime(2017, 1, 17, 0, 0)],
#  ['http://hud.gov:80/data.json',
#   datetime.datetime(2014, 5, 5, 0, 0),
#   datetime.datetime(2016, 12, 9, 0, 0)],
#  ['http://hud.gov:80/fairhousing%22',
#   datetime.datetime(2015, 2, 23, 0, 0),
#   datetime.datetime(2018, 3, 13, 0, 0)],
#  ['http://hud.gov:80/fathersday2011',
#   datetime.datetime(2011, 5, 12, 0, 0),
#   datetime.datetime(2017, 2, 18, 0, 0)],
#  ['http://www.hud.gov.:80/',
#   datetime.datetime(1997, 6, 1, 0, 0),
#   datetime.datetime(2019, 8, 19, 0, 0)],
#  ['http://www.hud.gov.:80/49mackte.html',
#   datetime.datetime(1997, 7, 26, 0, 0),
#   datetime.datetime(2017, 1, 18, 0, 0)],
#  ['http://www.hud.gov.:80/admshell.html',
#   datetime.datetime(1997, 7, 27, 0, 0),
#   datetime.datetime(2017, 9, 16, 0, 0)],
#  ['http://www.hud.gov.:80/aljshell.html',
#   datetime.datetime(1997, 7, 27, 0, 0),
#   datetime.datetime(2017, 9, 16, 0, 0)],
#  ['http://www.hud.gov.:80/awardny.html',
#   datetime.datetime(1997, 7, 27, 0, 0),
#   datetime.datetime(2013, 7, 3, 0, 0)],
#  ['http://www.hud.gov.:80/bcashell.html',
#   datetime.datetime(1997, 7, 27, 0, 0),
#   datetime.datetime(2017, 9, 16, 0, 0)],
#  ['http://www.hud.gov.:80/broker1.html',
#   datetime.datetime(1997, 6, 1, 0, 0),
#   datetime.datetime(2019, 1, 19, 0, 0)],
#  ['http://www.hud.gov.:80/bshelf4.html',
#   datetime.datetime(1997, 7, 26, 0, 0),
#   datetime.datetime(2017, 6, 30, 0, 0)],
#  ['http://www.hud.gov.:80/bshelf5.html',
#   datetime.datetime(1997, 7, 26, 0, 0),
#   datetime.datetime(2016, 12, 24, 0, 0)],
#  ['http://www.hud.gov.:80/buyhudhm.html',
#   datetime.datetime(1997, 7, 26, 0, 0),
#   datetime.datetime(2019, 1, 20, 0, 0)],
#  ['http://www.hud.gov.:80/cfo/cfohome.html',
#   datetime.datetime(1997, 6, 1, 0, 0),
#   datetime.datetime(2017, 9, 16, 0, 0)],
#  ['http://www.hud.gov.:80/cirshell.html',
#   datetime.datetime(1997, 7, 27, 0, 0),
#   datetime.datetime(2017, 9, 16, 0, 0)],
#  ['http://www.hud.gov.:80/citizen.html',
#   datetime.datetime(1997, 7, 26, 0, 0),
#   datetime.datetime(2019, 2, 17, 0, 0)],
#  ['http://www.hud.gov.:80/comdev.html',
#   datetime.datetime(1997, 7, 26, 0, 0),
#   datetime.datetime(2017, 6, 30, 0, 0)],
#  ['http://www.hud.gov.:80/commut.html',
#   datetime.datetime(1997, 7, 26, 0, 0),
#   datetime.datetime(2017, 6, 30, 0, 0)],
#  ['http://www.hud.gov.:80/consum.html',
#   datetime.datetime(1997, 6, 1, 0, 0),
#   datetime.datetime(2019, 1, 19, 0, 0)],
#  ['http://www.hud.gov.:80/cpd/',
#   datetime.datetime(1997, 6, 1, 0, 0),
#   datetime.datetime(2017, 1, 7, 0, 0)],
#  ['http://www.hud.gov.:80/cpd/c2020sft.html',
#   datetime.datetime(1997, 7, 26, 0, 0),
#   datetime.datetime(2013, 5, 21, 0, 0)],
#  ['http://www.hud.gov.:80/cpd/cdbg.html',
#   datetime.datetime(1997, 7, 26, 0, 0),
#   datetime.datetime(2017, 2, 9, 0, 0)],
#  ['http://www.hud.gov.:80/cpd/cdbgfct.html',
#   datetime.datetime(1997, 7, 27, 0, 0),
#   datetime.datetime(2013, 4, 13, 0, 0)],
#  ['http://www.hud.gov.:80/cpd/conplan.html',
#   datetime.datetime(1997, 7, 26, 0, 0),
#   datetime.datetime(2017, 12, 3, 0, 0)],
#  ['http://www.hud.gov.:80/cpd/cpdpr95a.html',
#   datetime.datetime(1997, 7, 26, 0, 0),
#   datetime.datetime(2016, 6, 19, 0, 0)],
#  ['http://www.hud.gov.:80/cpd/ezec/',
#   datetime.datetime(1997, 7, 26, 0, 0),
#   datetime.datetime(2017, 12, 6, 0, 0)],
#  ['http://www.hud.gov.:80/cpd/ezec/ezbyez.html',
#   datetime.datetime(1997, 7, 26, 0, 0),
#   datetime.datetime(2015, 7, 13, 0, 0)],
#  ['http://www.hud.gov.:80/cpd/ezec/ezeclist.html',
#   datetime.datetime(1997, 7, 27, 0, 0),
#   datetime.datetime(2015, 7, 13, 0, 0)],
#  ['http://www.hud.gov.:80/cpd/statefct.html',
#   datetime.datetime(1997, 6, 1, 0, 0),
#   datetime.datetime(2013, 4, 13, 0, 0)],
#  ['http://www.hud.gov.:80/cpes/la/shrevela.html',
#   datetime.datetime(1997, 6, 1, 0, 0),
#   datetime.datetime(2019, 5, 24, 0, 0)],
#  ['http://www.hud.gov.:80/cpes/mn/stpaulmn.html',
#   datetime.datetime(1997, 6, 1, 0, 0),
#   datetime.datetime(2017, 11, 13, 0, 0)],
#  ['http://www.hud.gov.:80/cpes/pa/buckscpa.html',
#   datetime.datetime(1997, 6, 1, 0, 0),
#   datetime.datetime(2018, 8, 31, 0, 0)],
#  ['http://www.hud.gov.:80/cts/ctshome.html',
#   datetime.datetime(1997, 6, 1, 0, 0),
#   datetime.datetime(2017, 9, 16, 0, 0)],
#  ['http://www.hud.gov.:80/directory/contents.html',
#   datetime.datetime(1997, 6, 1, 0, 0),
#   datetime.datetime(2017, 10, 12, 0, 0)],
#  ['http://www.hud.gov.:80/disabled.html',
#   datetime.datetime(1997, 6, 1, 0, 0),
#   datetime.datetime(2017, 11, 12, 0, 0)],
#  ['http://www.hud.gov.:80/fairhsg1.html',
#   datetime.datetime(1997, 6, 1, 0, 0),
#   datetime.datetime(2017, 12, 3, 0, 0)],
#  ['http://www.hud.gov.:80/fha/',
#   datetime.datetime(1997, 7, 26, 0, 0),
#   datetime.datetime(2019, 6, 13, 0, 0)],
#  ['http://www.hud.gov.:80/fha/fhahome.html/',
#   datetime.datetime(1997, 6, 1, 0, 0),
#   datetime.datetime(2019, 6, 17, 0, 0)],
#  ['http://www.hud.gov.:80/fha/fhains.html',
#   datetime.datetime(1997, 6, 1, 0, 0),
#   datetime.datetime(2016, 12, 24, 0, 0)],
#  ['http://www.hud.gov.:80/fha/mfh/mfhSec8.html',
#   datetime.datetime(1997, 7, 26, 0, 0),
#   datetime.datetime(2017, 4, 6, 0, 0)],
#  ['http://www.hud.gov.:80/fha/mletters/mltrmenu.html',
#   datetime.datetime(1997, 7, 26, 0, 0),
#   datetime.datetime(2019, 1, 19, 0, 0)],
#  ['http://www.hud.gov.:80/fha/res/respa_hm.html',
#   datetime.datetime(1997, 6, 1, 0, 0),
#   datetime.datetime(2013, 9, 16, 0, 0)],
#  ['http://www.hud.gov.:80/fha/sfh/mhs/mhscnsmr.html',
#   datetime.datetime(1997, 6, 1, 0, 0),
#   datetime.datetime(2017, 11, 15, 0, 0)],
#  ['http://www.hud.gov.:80/fha/sfh/mhs/mhshome.html',
#   datetime.datetime(1997, 6, 1, 0, 0),
#   datetime.datetime(2019, 2, 21, 0, 0)],
#  ['http://www.hud.gov.:80/fha/sfh/mhs/mhsmpsp.html',
#   datetime.datetime(1997, 7, 27, 0, 0),
#   datetime.datetime(2015, 3, 15, 0, 0)],
#  ['http://www.hud.gov.:80/fha/sfh/mhs/mhssaa.html',
#   datetime.datetime(1997, 6, 1, 0, 0),
#   datetime.datetime(2015, 3, 31, 0, 0)],
#  ['http://www.hud.gov.:80/fha/sfh/mhs/mhssht3.html',
#   datetime.datetime(1997, 7, 27, 0, 0),
#   datetime.datetime(2017, 11, 15, 0, 0)],
#  ['http://www.hud.gov.:80/fha/sfh/sfhhomeb.html',
#   datetime.datetime(1997, 7, 26, 0, 0),
#   datetime.datetime(2017, 4, 14, 0, 0)],
#  ['http://www.hud.gov.:80/fhe/fheact.html',
#   datetime.datetime(1997, 7, 26, 0, 0),
#   datetime.datetime(2019, 1, 6, 0, 0)],
#  ['http://www.hud.gov.:80/fhe/fheo.html',
#   datetime.datetime(1997, 7, 27, 0, 0),
#   datetime.datetime(2018, 12, 31, 0, 0)],
#  ['http://www.hud.gov.:80/fhe/fheologo.html',
#   datetime.datetime(1997, 7, 26, 0, 0),
#   datetime.datetime(2019, 1, 11, 0, 0)],
#  ['http://www.hud.gov.:80/fhefhag.html',
#   datetime.datetime(1997, 7, 26, 0, 0),
#   datetime.datetime(2016, 12, 19, 0, 0)],
#  ['http://www.hud.gov.:80/fhegtway.html',
#   datetime.datetime(1997, 7, 27, 0, 0),
#   datetime.datetime(2013, 9, 16, 0, 0)],
#  ['http://www.hud.gov.:80/forms/formwrhs.html',
#   datetime.datetime(1997, 6, 1, 0, 0),
#   datetime.datetime(2019, 4, 29, 0, 0)],
#  ['http://www.hud.gov.:80/fundopp.html',
#   datetime.datetime(1997, 6, 1, 0, 0),
#   datetime.datetime(2018, 5, 9, 0, 0)],
#  ['http://www.hud.gov.:80/govorhs.html',
#   datetime.datetime(1997, 7, 26, 0, 0),
#   datetime.datetime(2017, 1, 18, 0, 0)],
#  ['http://www.hud.gov.:80/hmbuyers.html',
#   datetime.datetime(1997, 6, 1, 0, 0),
#   datetime.datetime(2017, 11, 8, 0, 0)],
#  ['http://www.hud.gov.:80/hmless.html',
#   datetime.datetime(1997, 7, 27, 0, 0),
#   datetime.datetime(2017, 6, 21, 0, 0)],
#  ['http://www.hud.gov.:80/homeless.html',
#   datetime.datetime(1997, 7, 26, 0, 0),
#   datetime.datetime(2018, 8, 20, 0, 0)],
#  ['http://www.hud.gov.:80/homesale.html',
#   datetime.datetime(1997, 6, 1, 0, 0),
#   datetime.datetime(2017, 4, 7, 0, 0)],
#  ['http://www.hud.gov.:80/hudvet/vetfact.html',
#   datetime.datetime(1997, 7, 28, 0, 0),
#   datetime.datetime(2017, 7, 3, 0, 0)],
#  ['http://www.hud.gov.:80/hudvet/vethless.html',
#   datetime.datetime(1997, 7, 28, 0, 0),
#   datetime.datetime(2017, 8, 6, 0, 0)],
#  ['http://www.hud.gov.:80/hudvet/vetmain.html',
#   datetime.datetime(1997, 7, 27, 0, 0),
#   datetime.datetime(2019, 7, 12, 0, 0)],
#  ['http://www.hud.gov.:80/hudvet/vetres.html',
#   datetime.datetime(1997, 7, 28, 0, 0),
#   datetime.datetime(2017, 7, 3, 0, 0)],
#  ['http://www.hud.gov/?adid=www.nubianlink.net',
#   datetime.datetime(2013, 10, 29, 0, 0),
#   datetime.datetime(2013, 12, 29, 0, 0)],
#  ['http://www.hud.gov/?external-link',
#   datetime.datetime(2016, 3, 29, 0, 0),
#   datetime.datetime(2017, 6, 12, 0, 0)],
#  ['http://www.hud.gov/?keepThis=true&TB_iframe=true&height=650&width=850',
#   datetime.datetime(2016, 5, 2, 0, 0),
#   datetime.datetime(2019, 7, 20, 0, 0)],
#  ['http://www.hud.gov/about/staff/dwilliams.cfm',
#   datetime.datetime(2005, 10, 20, 0, 0),
#   datetime.datetime(2017, 3, 1, 0, 0)],
#  ['http://www.hud.gov/about/staff/kgottfried.cfm',
#   datetime.datetime(2005, 10, 20, 0, 0),
#   datetime.datetime(2019, 8, 13, 0, 0)],
#  ['http://www.hud.gov/about/staff/kkendrick.cfm',
#   datetime.datetime(2005, 10, 20, 0, 0),
#   datetime.datetime(2019, 2, 6, 0, 0)],
#  ['http://www.hud.gov/alabama/',
#   datetime.datetime(2006, 10, 7, 0, 0),
#   datetime.datetime(2015, 4, 26, 0, 0)],
#  ['http://www.hud.gov/apps/calendar/event.cfm?state=ak&record=12612&scheduleID=12357&calendarID=5',
#   datetime.datetime(2013, 3, 16, 0, 0),
#   datetime.datetime(2013, 3, 16, 0, 0)],
#  ['http://www.hud.gov/apps/calendar/event.cfm?state=ak&record=12674&scheduleID=12419&calendarID=5',
#   datetime.datetime(2013, 3, 16, 0, 0),
#   datetime.datetime(2013, 3, 16, 0, 0)],
#  ['http://www.hud.gov/apps/calendar/event.cfm?state=ak&record=12680&scheduleID=12425&calendarID=5',
#   datetime.datetime(2013, 3, 16, 0, 0),
#   datetime.datetime(2013, 3, 16, 0, 0)],
#  ['http://www.hud.gov/apps/calendar/event.cfm?state=ak&record=12681&scheduleID=12426&calendarID=5',
#   datetime.datetime(2013, 3, 16, 0, 0),
#   datetime.datetime(2013, 3, 16, 0, 0)],
#  ['http://www.hud.gov/apps/calendar/event.cfm?state=ak&record=12709&scheduleID=12454&calendarID=5',
#   datetime.datetime(2013, 3, 16, 0, 0),
#   datetime.datetime(2013, 3, 16, 0, 0)],
#  ['http://www.hud.gov/apps/calendar/event.cfm?state=ak&record=12759&scheduleID=12504&calendarID=5',
#   datetime.datetime(2013, 3, 16, 0, 0),
#   datetime.datetime(2013, 3, 16, 0, 0)],
#  ['http://www.hud.gov/apps/calendar/event.cfm?state=az&record=12554&scheduleID=12299&calendarID=6',
#   datetime.datetime(2013, 3, 16, 0, 0),
#   datetime.datetime(2013, 3, 16, 0, 0)],
#  ['http://www.hud.gov/apps/calendar/event.cfm?state=az&record=12748&scheduleID=12493&calendarID=6',
#   datetime.datetime(2013, 3, 16, 0, 0),
#   datetime.datetime(2013, 3, 16, 0, 0)],
#  ['http://www.hud.gov/apps/calendar/event.cfm?state=az&record=12756&scheduleID=12501&calendarID=6',
#   datetime.datetime(2013, 3, 16, 0, 0),
#   datetime.datetime(2013, 3, 16, 0, 0)],
#  ['http://www.hud.gov/apps/calendar/event.cfm?state=ca&record=10142&scheduleID=9903&calendarID=8',
#   datetime.datetime(2013, 3, 7, 0, 0),
#   datetime.datetime(2017, 2, 18, 0, 0)],
#  ['http://www.hud.gov/apps/calendar/event.cfm?state=ca&record=12748&scheduleID=12493&calendarID=8',
#   datetime.datetime(2013, 3, 17, 0, 0),
#   datetime.datetime(2013, 3, 17, 0, 0)],
#  ['http://www.hud.gov/apps/calendar/event.cfm?state=ca&record=12749&scheduleID=12494&calendarID=8',
#   datetime.datetime(2013, 3, 17, 0, 0),
#   datetime.datetime(2013, 3, 17, 0, 0)],
#  ['http://www.hud.gov/apps/calendar/event.cfm?state=co&record=12747&scheduleID=12492&calendarID=9',
#   datetime.datetime(2013, 3, 17, 0, 0),
#   datetime.datetime(2013, 3, 17, 0, 0)],
#  ['http://www.hud.gov/apps/calendar/event.cfm?state=co&record=12754&scheduleID=12499&calendarID=9',
#   datetime.datetime(2013, 3, 17, 0, 0),
#   datetime.datetime(2013, 3, 17, 0, 0)],
#  ['http://www.hud.gov/apps/section8/results.cfm?city_name_text=&county_name_text=Harford&zip_code=&property_name_text=&client_group_type=&maxrec=20&state_code=MD&statename=Maryland',
#   datetime.datetime(2013, 10, 1, 0, 0),
#   datetime.datetime(2019, 4, 17, 0, 0)],
#  ['http://www.hud.gov/apps/section8/results.cfm?city_name_text=&county_name_text=SAN+DIEGO&zip_code=&property_name_text=&client_group_type=&maxrec=20&state_code=CA&statename=California&start=101',
#   datetime.datetime(2013, 4, 1, 0, 0),
#   datetime.datetime(2013, 4, 1, 0, 0)],
#  ['http://www.hud.gov/apps/section8/results.cfm?city_name_text=&county_name_text=SAN+DIEGO&zip_code=&property_name_text=&client_group_type=&maxrec=20&state_code=CA&statename=California&start=21',
#   datetime.datetime(2013, 4, 1, 0, 0),
#   datetime.datetime(2013, 4, 1, 0, 0)],
#  ['http://www.hud.gov/apps/section8/results.cfm?city_name_text=&county_name_text=SAN+DIEGO&zip_code=&property_name_text=&client_group_type=&maxrec=20&state_code=CA&statename=California&start=41',
#   datetime.datetime(2013, 4, 1, 0, 0),
#   datetime.datetime(2013, 4, 1, 0, 0)],
#  ['http://www.hud.gov/apps/section8/results.cfm?city_name_text=&county_name_text=SAN+DIEGO&zip_code=&property_name_text=&client_group_type=&maxrec=20&state_code=CA&statename=California&start=61',
#   datetime.datetime(2013, 4, 1, 0, 0),
#   datetime.datetime(2013, 4, 1, 0, 0)],
#  ['http://www.hud.gov/apps/section8/results.cfm?city_name_text=&county_name_text=SAN+DIEGO&zip_code=&property_name_text=&client_group_type=&maxrec=20&state_code=CA&statename=California&start=81',
#   datetime.datetime(2013, 4, 1, 0, 0),
#   datetime.datetime(2013, 4, 1, 0, 0)],
#  ['http://www.hud.gov/apps/section8/step2.cfm?state=CT%2CConnecticut%20',
#   datetime.datetime(2013, 2, 21, 0, 0),
#   datetime.datetime(2019, 1, 10, 0, 0)],
#  ['http://www.hud.gov/apps/section8/step2.cfm?state=KS,%20Kansas',
#   datetime.datetime(2013, 2, 20, 0, 0),
#   datetime.datetime(2019, 1, 10, 0, 0)],
#  ['http://www.hud.gov/apps/section8/step2.cfm?state=MO,%20Missouri',
#   datetime.datetime(2013, 2, 22, 0, 0),
#   datetime.datetime(2019, 1, 11, 0, 0)],
#  ['http://www.hud.gov/apps/section8/step2.cfm?state=NJ%2CNewJersey',
#   datetime.datetime(2013, 2, 21, 0, 0),
#   datetime.datetime(2016, 12, 2, 0, 0)],
#  ['http://www.hud.gov/apps/section8/step2.cfm?state=NM%2CNewMexico',
#   datetime.datetime(2006, 9, 30, 0, 0),
#   datetime.datetime(2013, 2, 21, 0, 0)],
#  ['http://www.hud.gov/apps/section8/step2.cfm?state=PA,%20Pennsylvania%20',
#   datetime.datetime(2013, 2, 27, 0, 0),
#   datetime.datetime(2013, 2, 27, 0, 0)],
#  ['http://www.hud.gov/apps/section8/step2.cfm?state=VA,%20Virginia',
#   datetime.datetime(2006, 9, 29, 0, 0),
#   datetime.datetime(2013, 2, 21, 0, 0)],
#  ['http://www.hud.gov/apps/section8/step2.cfm?state=WV,%20West%20Virginia',
#   datetime.datetime(2006, 9, 29, 0, 0),
#   datetime.datetime(2013, 2, 21, 0, 0)],
#  ['http://www.hud.gov/assist/webpolicies.cfm',
#   datetime.datetime(2005, 9, 7, 0, 0),
#   datetime.datetime(2018, 9, 26, 0, 0)],
#  ['http://www.hud.gov/assist/webpolicies.cfm?&lang=en',
#   datetime.datetime(2005, 9, 10, 0, 0),
#   datetime.datetime(2013, 3, 2, 0, 0)],
#  ['http://www.hud.gov/budgetsummary2010/index.cfm',
#   datetime.datetime(2009, 5, 12, 0, 0),
#   datetime.datetime(2017, 1, 18, 0, 0)],
#  ['http://www.hud.gov/budgetsummary2010/index.cfm?&lang=en',
#   datetime.datetime(2013, 2, 22, 0, 0),
#   datetime.datetime(2013, 2, 22, 0, 0)],
#  ['http://www.hud.gov/buying/loans.cfm',
#   datetime.datetime(2005, 10, 26, 0, 0),
#   datetime.datetime(2019, 5, 6, 0, 0)],
#  ['http://www.hud.gov/california',
#   datetime.datetime(2013, 4, 25, 0, 0),
#   datetime.datetime(2017, 2, 9, 0, 0)],
#  ['http://www.hud.gov/complaints/housediscrim.cfm?&lang=en',
#   datetime.datetime(2005, 10, 22, 0, 0),
#   datetime.datetime(2013, 2, 28, 0, 0)],
#  ['http://www.hud.gov/connecticut',
#   datetime.datetime(2015, 12, 21, 0, 0),
#   datetime.datetime(2015, 12, 21, 0, 0)],
#  ['http://www.hud.gov/counseling',
#   datetime.datetime(2006, 10, 5, 0, 0),
#   datetime.datetime(2019, 7, 9, 0, 0)],
#  ['http://www.hud.gov/cpd/c2020/colonias/ca.jpg',
#   datetime.datetime(2013, 2, 23, 0, 0),
#   datetime.datetime(2013, 2, 23, 0, 0)],
#  ['http://www.hud.gov/cpd/c2020/colonias/nm.jpg',
#   datetime.datetime(2013, 2, 23, 0, 0),
#   datetime.datetime(2013, 2, 23, 0, 0)],
#  ['http://www.hud.gov/cpd/hhpass.gif',
#   datetime.datetime(2013, 10, 23, 0, 0),
#   datetime.datetime(2013, 10, 23, 0, 0)],
#  ['http://www.hud.gov/cpd/home/homeweb.html;MARY_KOLESAR@hud.gov',
#   datetime.datetime(2010, 1, 5, 0, 0),
#   datetime.datetime(2013, 9, 28, 0, 0)],
#  ['http://www.hud.gov/cpd/idis.gif',
#   datetime.datetime(2013, 10, 23, 0, 0),
#   datetime.datetime(2013, 10, 23, 0, 0)],
#  ['http://www.hud.gov/cpd/idis/back.jpg',
#   datetime.datetime(2013, 10, 23, 0, 0),
#   datetime.datetime(2013, 10, 23, 0, 0)],
#  ['http://www.hud.gov/cpd/images/cpd10b.gif',
#   datetime.datetime(2013, 2, 6, 0, 0),
#   datetime.datetime(2013, 2, 8, 0, 0)],
#  ['http://www.hud.gov/digitalstrategy',
#   datetime.datetime(2015, 7, 6, 0, 0),
#   datetime.datetime(2016, 6, 17, 0, 0)],
#  ['http://www.hud.gov/districtofcolumbia',
#   datetime.datetime(2015, 10, 16, 0, 0),
#   datetime.datetime(2016, 1, 22, 0, 0)],
#  ['http://www.hud.gov/emarc/index.cfm',
#   datetime.datetime(2013, 3, 3, 0, 0),
#   datetime.datetime(2017, 7, 3, 0, 0)],
#  ['http://www.hud.gov/emarc/index.cfm?fuseaction=emar.addRegisterEvent&eventId=2153&update=N',
#   datetime.datetime(2015, 8, 15, 0, 0),
#   datetime.datetime(2015, 8, 15, 0, 0)],
#  ['http://www.hud.gov/emarc/index.cfm?fuseaction=emar.addRegisterEvent&eventId=2286&update=N',
#   datetime.datetime(2015, 9, 25, 0, 0),
#   datetime.datetime(2015, 9, 25, 0, 0)],
#  ['http://www.hud.gov/emarc/index.cfm?fuseaction=emar.registerEvent&eventId=1177&update=N',
#   datetime.datetime(2013, 2, 20, 0, 0),
#   datetime.datetime(2017, 1, 1, 0, 0)],
#  ['http://www.hud.gov/emarc/index.cfm?fuseaction=emar.registerEvent&eventId=1241&update=N',
#   datetime.datetime(2013, 3, 10, 0, 0),
#   datetime.datetime(2013, 3, 10, 0, 0)],
#  ['http://www.hud.gov/emarc/index.cfm?fuseaction=emar.registerEvent&eventId=1583&update=N',
#   datetime.datetime(2013, 2, 21, 0, 0),
#   datetime.datetime(2013, 2, 21, 0, 0)],
#  ['http://www.hud.gov/emarc/index.cfm?fuseaction=emar.registerEvent&eventId=1593&update=N',
#   datetime.datetime(2013, 9, 9, 0, 0),
#   datetime.datetime(2013, 9, 9, 0, 0)],
#  ['http://www.hud.gov/emarc/index.cfm?fuseaction=emar.registerEvent&eventId=2009&update=N',
#   datetime.datetime(2014, 11, 22, 0, 0),
#   datetime.datetime(2014, 11, 22, 0, 0)],
#  ['http://www.hud.gov/emarc/index.cfm?fuseaction=emar.registerEvent&eventId=2053&update=N',
#   datetime.datetime(2016, 1, 28, 0, 0),
#   datetime.datetime(2016, 1, 28, 0, 0)],
#  ['http://www.hud.gov/emarc/index.cfm?fuseaction=emar.registerEvent&eventId=2341&update=N',
#   datetime.datetime(2015, 9, 25, 0, 0),
#   datetime.datetime(2015, 9, 25, 0, 0)],
#  ['http://www.hud.gov/emarc/index.cfm?fuseaction=emar.registerEvent&eventId=2348&update=N',
#   datetime.datetime(2015, 9, 25, 0, 0),
#   datetime.datetime(2015, 9, 25, 0, 0)],
#  ['http://www.hud.gov/emarc/index.cfm?fuseaction=emar.registerEvent&eventId=2418&update=N',
#   datetime.datetime(2015, 8, 23, 0, 0),
#   datetime.datetime(2015, 8, 23, 0, 0)],
#  ['http://www.hud.gov/emarc/index.cfm?fuseaction=emar.registerEventSearch',
#   datetime.datetime(2009, 5, 12, 0, 0),
#   datetime.datetime(2018, 10, 22, 0, 0)],
#  ['http://www.hud.gov/emarc/index.cfm?fuseaction=emar.registerEventSearch&pass_submit=1',
#   datetime.datetime(2009, 5, 12, 0, 0),
#   datetime.datetime(2016, 12, 2, 0, 0)],
#  ['http://www.hud.gov/emarc/index.cfm?fuseaction=emar.registrationHome',
#   datetime.datetime(2009, 5, 12, 0, 0),
#   datetime.datetime(2018, 10, 22, 0, 0)],
#  ['http://www.hud.gov/emarc/index.cfm?fuseaction=emar.registrationNotOpenError&eventid=1583',
#   datetime.datetime(2013, 2, 21, 0, 0),
#   datetime.datetime(2013, 2, 21, 0, 0)],
#  ['http://www.hud.gov/emarc/index.cfm?fuseaction=emar.registrationNotOpenError&eventid=1593',
#   datetime.datetime(2013, 12, 21, 0, 0),
#   datetime.datetime(2013, 12, 21, 0, 0)],
#  ['http://www.hud.gov/emarc/index.cfm?fuseaction=emar.registrationNotOpenError&eventid=2153',
#   datetime.datetime(2015, 8, 16, 0, 0),
#   datetime.datetime(2015, 8, 16, 0, 0)],
#  ['http://www.hud.gov/emarc/index.cfm?fuseaction=emar.registrationNotOpenError&eventid=2418',
#   datetime.datetime(2015, 8, 23, 0, 0),
#   datetime.datetime(2015, 8, 23, 0, 0)],
#  ['http://www.hud.gov/emarc/index.cfm?fuseaction=emarc.error&CFID=20892032&CFTOKEN=22613189',
#   datetime.datetime(2009, 5, 14, 0, 0),
#   datetime.datetime(2013, 2, 20, 0, 0)],
#  ['http://www.hud.gov/energystar/developers.cfm',
#   datetime.datetime(2004, 11, 5, 0, 0),
#   datetime.datetime(2013, 5, 2, 0, 0)],
#  ['http://www.hud.gov/energystar/grantees.cfm',
#   datetime.datetime(2004, 10, 21, 0, 0),
#   datetime.datetime(2017, 4, 9, 0, 0)],
#  ['http://www.hud.gov/fha/loans.cfm',
#   datetime.datetime(2005, 9, 7, 0, 0),
#   datetime.datetime(2019, 6, 14, 0, 0)],
#  ['http://www.hud.gov/fhcomplaints',
#   datetime.datetime(2006, 10, 5, 0, 0),
#   datetime.datetime(2013, 11, 12, 0, 0)],
#  ['http://www.hud.gov/findacounselor',
#   datetime.datetime(2015, 9, 13, 0, 0),
#   datetime.datetime(2019, 6, 16, 0, 0)],
#  ['http://www.hud.gov/FOIA',
#   datetime.datetime(2016, 5, 14, 0, 0),
#   datetime.datetime(2019, 4, 29, 0, 0)],
#  ['http://www.hud.gov/foreclosure/index.cfm?&lang=es',
#   datetime.datetime(2016, 2, 4, 0, 0),
#   datetime.datetime(2016, 2, 4, 0, 0)],
#  ['http://www.hud.gov/groups/contacts.cfm',
#   datetime.datetime(2004, 10, 31, 0, 0),
#   datetime.datetime(2013, 3, 1, 0, 0)],
#  ['http://www.hud.gov/groups/farmwkercolonia.cfm',
#   datetime.datetime(2004, 10, 31, 0, 0),
#   datetime.datetime(2017, 1, 18, 0, 0)],
#  ['http://www.hud.gov/groups/funding.cfm',
#   datetime.datetime(2004, 10, 31, 0, 0),
#   datetime.datetime(2013, 3, 1, 0, 0)],
#  ['http://www.hud.gov/groups/hudprograms.cfm',
#   datetime.datetime(2004, 11, 10, 0, 0),
#   datetime.datetime(2016, 10, 6, 0, 0)],
#  ['http://www.hud.gov/groups/library.cfm',
#   datetime.datetime(2004, 10, 31, 0, 0),
#   datetime.datetime(2013, 3, 1, 0, 0)],
#  ['http://www.hud.gov/groups/organization.cfm',
#   datetime.datetime(2004, 10, 31, 0, 0),
#   datetime.datetime(2013, 3, 1, 0, 0)],
#  ['http://www.hud.gov/hudhomes',
#   datetime.datetime(2006, 10, 5, 0, 0),
#   datetime.datetime(2019, 7, 5, 0, 0)],
#  ['http://www.hud.gov:80/232forms',
#   datetime.datetime(2016, 1, 16, 0, 0),
#   datetime.datetime(2017, 12, 4, 0, 0)],
#  ['http://www.hud.gov:80/50',
#   datetime.datetime(2015, 8, 10, 0, 0),
#   datetime.datetime(2015, 9, 5, 0, 0)],
#  ['http://www.hud.gov:80/?NF=1',
#   datetime.datetime(2003, 11, 25, 0, 0),
#   datetime.datetime(2017, 1, 31, 0, 0)],
#  ['http://www.hud.gov:80/?res=1024&ver=true',
#   datetime.datetime(2002, 6, 10, 0, 0),
#   datetime.datetime(2017, 12, 28, 0, 0)],
#  ['http://www.hud.gov:80/?Trade%20Data%20Centerr=www.Tradedc.com',
#   datetime.datetime(2008, 12, 18, 0, 0),
#   datetime.datetime(2013, 10, 31, 0, 0)],
#  ['http://www.hud.gov:80/about/',
#   datetime.datetime(2001, 2, 7, 0, 0),
#   datetime.datetime(2019, 8, 1, 0, 0)],
#  ['http://www.hud.gov:80/about/acronyms.cfm',
#   datetime.datetime(2002, 6, 2, 0, 0),
#   datetime.datetime(2016, 6, 6, 0, 0)],
#  ['http://www.hud.gov:80/about/acronyms.cfm?state=az',
#   datetime.datetime(2003, 6, 28, 0, 0),
#   datetime.datetime(2015, 9, 29, 0, 0)],
#  ['http://www.hud.gov:80/about/hqbuilding.cfm',
#   datetime.datetime(2001, 8, 3, 0, 0),
#   datetime.datetime(2018, 1, 17, 0, 0)],
#  ['http://www.hud.gov:80/about/index.cfm',
#   datetime.datetime(2001, 1, 31, 0, 0),
#   datetime.datetime(2019, 1, 10, 0, 0)],
#  ['http://www.hud.gov:80/about/index.cfm?&lang=en',
#   datetime.datetime(2003, 2, 26, 0, 0),
#   datetime.datetime(2013, 2, 22, 0, 0)],
#  ['http://www.hud.gov:80/about/inventory.cfm/',
#   datetime.datetime(2004, 12, 9, 0, 0),
#   datetime.datetime(2013, 5, 13, 0, 0)],
#  ['http://www.hud.gov:80/about/keyhq.cfm',
#   datetime.datetime(2006, 6, 16, 0, 0),
#   datetime.datetime(2019, 1, 10, 0, 0)],
#  ['http://www.hud.gov:80/about/qaintro.cfm',
#   datetime.datetime(2001, 11, 15, 0, 0),
#   datetime.datetime(2018, 10, 26, 0, 0)],
#  ['http://www.hud.gov:80/about/secretary/',
#   datetime.datetime(2001, 3, 3, 0, 0),
#   datetime.datetime(2019, 8, 19, 0, 0)],
#  ['http://www.hud.gov:80/about/secretary/bernardibio.cfm',
#   datetime.datetime(2004, 6, 3, 0, 0),
#   datetime.datetime(2018, 11, 16, 0, 0)],
#  ['http://www.hud.gov:80/about/secretary/donohuebio.cfm',
#   datetime.datetime(2002, 12, 29, 0, 0),
#   datetime.datetime(2019, 5, 2, 0, 0)],
#  ['http://www.hud.gov:80/about/secretary/donovanbio.cfm',
#   datetime.datetime(2009, 2, 21, 0, 0),
#   datetime.datetime(2018, 6, 13, 0, 0)],
#  ['http://www.hud.gov:80/about/secretary/hudsecy.cfm',
#   datetime.datetime(2001, 3, 3, 0, 0),
#   datetime.datetime(2019, 1, 18, 0, 0)],
#  ['http://www.hud.gov:80/about/secretary/jacksonbio.cfm',
#   datetime.datetime(2001, 11, 7, 0, 0),
#   datetime.datetime(2019, 7, 26, 0, 0)],
#  ['http://www.hud.gov:80/about/secretary/prestonbio.cfm',
#   datetime.datetime(2008, 7, 11, 0, 0),
#   datetime.datetime(2016, 4, 11, 0, 0)],
#  ['http://www.hud.gov:80/about/section8.cfm',
#   datetime.datetime(2001, 12, 21, 0, 0),
#   datetime.datetime(2018, 8, 20, 0, 0)],
#  ['http://www.hud.gov:80/AFFH',
#   datetime.datetime(2015, 7, 18, 0, 0),
#   datetime.datetime(2016, 6, 11, 0, 0)],
#  ['http://www.hud.gov:80/alaska',
#   datetime.datetime(2012, 8, 25, 0, 0),
#   datetime.datetime(2015, 9, 25, 0, 0)],
#  ['http://www.hud.gov:80/answers',
#   datetime.datetime(2011, 9, 26, 0, 0),
#   datetime.datetime(2019, 7, 22, 0, 0)],
#  ['http://www.hud.gov:80/answers.',
#   datetime.datetime(2015, 1, 8, 0, 0),
#   datetime.datetime(2015, 3, 16, 0, 0)],
#  ['http://www.hud.gov:80/anytown/anytown.html',
#   datetime.datetime(1998, 12, 2, 0, 0),
#   datetime.datetime(2016, 3, 5, 0, 0)],
#  ['http://www.hud.gov:80/anytown/map.html',
#   datetime.datetime(1999, 5, 8, 0, 0),
#   datetime.datetime(2016, 12, 15, 0, 0)],
#  ['http://www.hud.gov:80/anytown/police.html',
#   datetime.datetime(2016, 4, 7, 0, 0),
#   datetime.datetime(2016, 5, 11, 0, 0)],
#  ['http://www.hud.gov:80/appraisers/',
#   datetime.datetime(2008, 9, 29, 0, 0),
#   datetime.datetime(2017, 5, 20, 0, 0)],
#  ['http://www.hud.gov:80/apps/section8/',
#   datetime.datetime(2003, 8, 16, 0, 0),
#   datetime.datetime(2019, 2, 13, 0, 0)],
#  ['http://www.hud.gov:80/apps/section8/index.cfm',
#   datetime.datetime(2002, 10, 17, 0, 0),
#   datetime.datetime(2019, 8, 1, 0, 0)],
#  ['http://www.hud.gov:80/apps/section8/index.cfm?CFID=1000762&CFTOKEN=15306169',
#   datetime.datetime(2007, 8, 9, 0, 0),
#   datetime.datetime(2017, 11, 12, 0, 0)],
#  ['http://www.hud.gov:80/apps/section8/results.cfm?city_name_text=&county_name_text=SAN+DIEGO&zip_code=&property_name_text=&client_group_type=&maxrec=20&state_code=CA&statename=California',
#   datetime.datetime(2007, 1, 4, 0, 0),
#   datetime.datetime(2013, 4, 1, 0, 0)],
#  ['http://www.hud.gov:80/apps/section8/step2.cfm?state=AK,Alaska',
#   datetime.datetime(2002, 12, 20, 0, 0),
#   datetime.datetime(2017, 7, 19, 0, 0)],
#  ['http://www.hud.gov:80/apps/section8/step2.cfm?state=AL,Alabama',
#   datetime.datetime(2003, 4, 2, 0, 0),
#   datetime.datetime(2017, 7, 19, 0, 0)],
#  ['http://www.hud.gov:80/apps/section8/step2.cfm?state=AR,Arkansas',
#   datetime.datetime(2003, 2, 6, 0, 0),
#   datetime.datetime(2019, 1, 11, 0, 0)],
#  ['http://www.hud.gov:80/apps/section8/step2.cfm?state=AZ,Arizona',
#   datetime.datetime(2003, 4, 23, 0, 0),
#   datetime.datetime(2019, 1, 11, 0, 0)],
#  ['http://www.hud.gov:80/apps/section8/step2.cfm?state=CA,California',
#   datetime.datetime(2003, 2, 21, 0, 0),
#   datetime.datetime(2019, 2, 3, 0, 0)],
#  ['http://www.hud.gov:80/apps/section8/step2.cfm?state=CO,Colorado',
#   datetime.datetime(2003, 4, 21, 0, 0),
#   datetime.datetime(2019, 1, 11, 0, 0)],
#  ['http://www.hud.gov:80/apps/section8/step2.cfm?state=CT,Connecticut',
#   datetime.datetime(2003, 2, 5, 0, 0),
#   datetime.datetime(2017, 7, 19, 0, 0)],
#  ['http://www.hud.gov:80/apps/section8/step2.cfm?state=DC',
#   datetime.datetime(2005, 2, 9, 0, 0),
#   datetime.datetime(2013, 2, 21, 0, 0)],
#  ['http://www.hud.gov:80/apps/section8/step2.cfm?state=DC,District+of+Columbia',
#   datetime.datetime(2003, 10, 2, 0, 0),
#   datetime.datetime(2015, 7, 21, 0, 0)],
#  ['http://www.hud.gov:80/apps/section8/step2.cfm?state=DE',
#   datetime.datetime(2005, 2, 9, 0, 0),
#   datetime.datetime(2013, 2, 21, 0, 0)],
#  ['http://www.hud.gov:80/apps/section8/step2.cfm?state=DE,Delaware',
#   datetime.datetime(2003, 10, 16, 0, 0),
#   datetime.datetime(2017, 7, 19, 0, 0)],
#  ['http://www.hud.gov:80/apps/section8/step2.cfm?state=FL,Florida',
#   datetime.datetime(2003, 6, 28, 0, 0),
#   datetime.datetime(2019, 6, 18, 0, 0)],
#  ['http://www.hud.gov:80/apps/section8/step2.cfm?state=GA,Georgia',
#   datetime.datetime(2003, 2, 23, 0, 0),
#   datetime.datetime(2017, 6, 7, 0, 0)],
#  ['http://www.hud.gov:80/apps/section8/step2.cfm?state=HI,Hawaii',
#   datetime.datetime(2003, 9, 21, 0, 0),
#   datetime.datetime(2019, 1, 11, 0, 0)],
#  ['http://www.hud.gov:80/apps/section8/step2.cfm?state=IA,Iowa',
#   datetime.datetime(2002, 12, 28, 0, 0),
#   datetime.datetime(2019, 1, 11, 0, 0)],
#  ['http://www.hud.gov:80/apps/section8/step2.cfm?state=ID,Idaho',
#   datetime.datetime(2003, 2, 6, 0, 0),
#   datetime.datetime(2017, 8, 2, 0, 0)],
#  ['http://www.hud.gov:80/apps/section8/step2.cfm?state=IL,Illinois',
#   datetime.datetime(2003, 8, 4, 0, 0),
#   datetime.datetime(2019, 1, 11, 0, 0)],
#  ['http://www.hud.gov:80/apps/section8/step2.cfm?state=IN,Indiana',
#   datetime.datetime(2003, 8, 27, 0, 0),
#   datetime.datetime(2019, 1, 10, 0, 0)],
#  ['http://www.hud.gov:80/apps/section8/step2.cfm?state=KS,Kansas',
#   datetime.datetime(2003, 7, 27, 0, 0),
#   datetime.datetime(2017, 7, 19, 0, 0)],
#  ['http://www.hud.gov:80/apps/section8/step2.cfm?state=KY,Kentucky',
#   datetime.datetime(2003, 7, 24, 0, 0),
#   datetime.datetime(2018, 1, 12, 0, 0)],
#  ['http://www.hud.gov:80/apps/section8/step2.cfm?state=LA,Louisiana',
#   datetime.datetime(2003, 2, 21, 0, 0),
#   datetime.datetime(2019, 1, 11, 0, 0)],
#  ['http://www.hud.gov:80/apps/section8/step2.cfm?state=MA,Massachusetts',
#   datetime.datetime(2003, 2, 6, 0, 0),
#   datetime.datetime(2019, 1, 10, 0, 0)],
#  ['http://www.hud.gov:80/apps/section8/step2.cfm?state=MD',
#   datetime.datetime(2005, 2, 6, 0, 0),
#   datetime.datetime(2017, 1, 1, 0, 0)],
#  ['http://www.hud.gov:80/apps/section8/step2.cfm?state=MD,Maryland',
#   datetime.datetime(2003, 8, 29, 0, 0),
#   datetime.datetime(2018, 12, 4, 0, 0)],
#  ['http://www.hud.gov:80/apps/section8/step2.cfm?state=ME,Maine',
#   datetime.datetime(2002, 12, 29, 0, 0),
#   datetime.datetime(2019, 1, 11, 0, 0)],
#  ['http://www.hud.gov:80/apps/section8/step2.cfm?state=MI,Michigan',
#   datetime.datetime(2003, 8, 29, 0, 0),
#   datetime.datetime(2019, 3, 5, 0, 0)],
#  ['http://www.hud.gov:80/apps/section8/step2.cfm?state=MN,Minnesota',
#   datetime.datetime(2002, 10, 23, 0, 0),
#   datetime.datetime(2019, 8, 7, 0, 0)],
#  ['http://www.hud.gov:80/apps/section8/step2.cfm?state=MO,Missouri',
#   datetime.datetime(2003, 4, 15, 0, 0),
#   datetime.datetime(2019, 1, 28, 0, 0)],
#  ['http://www.hud.gov:80/apps/section8/step2.cfm?state=MS,Mississippi',
#   datetime.datetime(2003, 4, 15, 0, 0),
#   datetime.datetime(2017, 7, 19, 0, 0)],
#  ['http://www.hud.gov:80/apps/section8/step2.cfm?state=MT,Montana',
#   datetime.datetime(2003, 8, 18, 0, 0),
#   datetime.datetime(2019, 1, 25, 0, 0)],
#  ['http://www.hud.gov:80/apps/section8/step2.cfm?state=NC,North+Carolina',
#   datetime.datetime(2003, 4, 18, 0, 0),
#   datetime.datetime(2015, 7, 21, 0, 0)],
#  ['http://www.hud.gov:80/apps/section8/step2.cfm?state=ND,North+Dakota',
#   datetime.datetime(2003, 4, 18, 0, 0),
#   datetime.datetime(2017, 7, 19, 0, 0)],
#  ['http://www.hud.gov:80/apps/section8/step2.cfm?state=NE,Nebraska',
#   datetime.datetime(2003, 4, 15, 0, 0),
#   datetime.datetime(2017, 7, 19, 0, 0)],
#  ['http://www.hud.gov:80/apps/section8/step2.cfm?state=NH,New+Hampshire',
#   datetime.datetime(2003, 8, 29, 0, 0),
#   datetime.datetime(2017, 7, 19, 0, 0)],
#  ['http://www.hud.gov:80/apps/section8/step2.cfm?state=NH,NewHampshire',
#   datetime.datetime(2003, 2, 6, 0, 0),
#   datetime.datetime(2013, 2, 20, 0, 0)],
#  ['http://www.hud.gov:80/apps/section8/step2.cfm?state=NJ,New+Jersey',
#   datetime.datetime(2002, 12, 20, 0, 0),
#   datetime.datetime(2017, 7, 15, 0, 0)],
#  ['http://www.hud.gov:80/apps/section8/step2.cfm?state=NM,New+Mexico',
#   datetime.datetime(2003, 4, 5, 0, 0),
#   datetime.datetime(2017, 7, 19, 0, 0)],
#  ['http://www.hud.gov:80/apps/section8/step2.cfm?state=NV,Nevada',
#   datetime.datetime(2003, 8, 18, 0, 0),
#   datetime.datetime(2017, 7, 19, 0, 0)],
#  ['http://www.hud.gov:80/apps/section8/step2.cfm?state=NY%2CNewyork',
#   datetime.datetime(2006, 5, 18, 0, 0),
#   datetime.datetime(2013, 2, 21, 0, 0)],
#  ['http://www.hud.gov:80/apps/section8/step2.cfm?state=NY,New+York',
#   datetime.datetime(2003, 2, 6, 0, 0),
#   datetime.datetime(2018, 11, 12, 0, 0)],
#  ['http://www.hud.gov:80/apps/section8/step2.cfm?state=OH,ohio',
#   datetime.datetime(2003, 1, 17, 0, 0),
#   datetime.datetime(2015, 9, 8, 0, 0)],
#  ['http://www.hud.gov:80/apps/section8/step2.cfm?state=OK,Oklahoma',
#   datetime.datetime(2003, 2, 6, 0, 0),
#   datetime.datetime(2019, 7, 8, 0, 0)],
#  ['http://www.hud.gov:80/apps/section8/step2.cfm?state=OR',
#   datetime.datetime(2003, 4, 22, 0, 0),
#   datetime.datetime(2018, 3, 4, 0, 0)],
#  ['http://www.hud.gov:80/apps/section8/step2.cfm?state=OR,Oregon',
#   datetime.datetime(2002, 12, 20, 0, 0),
#   datetime.datetime(2017, 7, 22, 0, 0)],
#  ['http://www.hud.gov:80/apps/section8/step2.cfm?state=PA,%20Pennsylvania',
#   datetime.datetime(2005, 2, 21, 0, 0),
#   datetime.datetime(2015, 3, 24, 0, 0)],
#  ['http://www.hud.gov:80/apps/section8/step2.cfm?state=PA,Pennsylvania',
#   datetime.datetime(2003, 9, 20, 0, 0),
#   datetime.datetime(2017, 10, 26, 0, 0)],
#  ['http://www.hud.gov:80/apps/section8/step2.cfm?state=PR,Puerto+Rico',
#   datetime.datetime(2003, 8, 4, 0, 0),
#   datetime.datetime(2019, 8, 16, 0, 0)],
#  ['http://www.hud.gov:80/apps/section8/step2.cfm?state=RI,Rhode+Island',
#   datetime.datetime(2003, 2, 19, 0, 0),
#   datetime.datetime(2017, 7, 19, 0, 0)],
#  ['http://www.hud.gov:80/apps/section8/step2.cfm?state=RI,RhodeIsland',
#   datetime.datetime(2003, 2, 6, 0, 0),
#   datetime.datetime(2013, 2, 20, 0, 0)],
#  ['http://www.hud.gov:80/apps/section8/step2.cfm?state=SC,South+Carolina',
#   datetime.datetime(2003, 10, 4, 0, 0),
#   datetime.datetime(2017, 7, 19, 0, 0)],
#  ['http://www.hud.gov:80/apps/section8/step2.cfm?state=SD,South+Dakota',
#   datetime.datetime(2002, 12, 28, 0, 0),
#   datetime.datetime(2017, 7, 19, 0, 0)],
#  ['http://www.hud.gov:80/apps/section8/step2.cfm?state=TN,Tennessee',
#   datetime.datetime(2003, 4, 15, 0, 0),
#   datetime.datetime(2017, 7, 19, 0, 0)],
#  ['http://www.hud.gov:80/apps/section8/step2.cfm?state=TX,Texas',
#   datetime.datetime(2003, 2, 21, 0, 0),
#   datetime.datetime(2019, 1, 9, 0, 0)],
#  ['http://www.hud.gov:80/apps/section8/step2.cfm?state=UT,Utah',
#   datetime.datetime(2003, 6, 22, 0, 0),
#   datetime.datetime(2017, 7, 19, 0, 0)],
#  ['http://www.hud.gov:80/apps/section8/step2.cfm?state=VA,Virginia',
#   datetime.datetime(2003, 9, 30, 0, 0),
#   datetime.datetime(2017, 7, 19, 0, 0)],
#  ['http://www.hud.gov:80/apps/section8/step2.cfm?state=VT,Vermont',
#   datetime.datetime(2003, 2, 22, 0, 0),
#   datetime.datetime(2018, 9, 7, 0, 0)],
#  ['http://www.hud.gov:80/apps/section8/step2.cfm?state=WA,Washington',
#   datetime.datetime(2002, 10, 23, 0, 0),
#   datetime.datetime(2017, 7, 7, 0, 0)],
#  ['http://www.hud.gov:80/apps/section8/step2.cfm?state=WI,Wisconsin',
#   datetime.datetime(2003, 8, 16, 0, 0),
#   datetime.datetime(2018, 12, 3, 0, 0)],
#  ['http://www.hud.gov:80/apps/section8/step2.cfm?state=WV,West+Virginia',
#   datetime.datetime(2003, 8, 31, 0, 0),
#   datetime.datetime(2017, 7, 19, 0, 0)],
#  ['http://www.hud.gov:80/apps/section8/step2.cfm?state=WY,Wyoming',
#   datetime.datetime(2003, 4, 19, 0, 0),
#   datetime.datetime(2019, 1, 10, 0, 0)],
#  ['http://www.hud.gov:80/arizona',
#   datetime.datetime(2013, 9, 27, 0, 0),
#   datetime.datetime(2013, 9, 27, 0, 0)],
#  ['http://www.hud.gov:80/arkansas',
#   datetime.datetime(2013, 2, 25, 0, 0),
#   datetime.datetime(2017, 12, 26, 0, 0)],
#  ['http://www.hud.gov:80/assist',
#   datetime.datetime(2001, 7, 1, 0, 0),
#   datetime.datetime(2019, 1, 9, 0, 0)],
#  ['http://www.hud.gov:80/assist/acrobat.cfm',
#   datetime.datetime(2002, 4, 15, 0, 0),
#   datetime.datetime(2015, 9, 18, 0, 0)],
#  ['http://www.hud.gov:80/assist/contactus.cfm',
#   datetime.datetime(2001, 1, 31, 0, 0),
#   datetime.datetime(2017, 11, 9, 0, 0)],
#  ['http://www.hud.gov:80/assist/contactus.cfm?&lang=en',
#   datetime.datetime(2003, 4, 13, 0, 0),
#   datetime.datetime(2013, 2, 28, 0, 0)],
#  ['http://www.hud.gov:80/assist/cookies.cfm',
#   datetime.datetime(2001, 3, 29, 0, 0),
#   datetime.datetime(2015, 9, 13, 0, 0)],
#  ['http://www.hud.gov:80/assist/index.cfm',
#   datetime.datetime(2001, 1, 31, 0, 0),
#   datetime.datetime(2016, 12, 29, 0, 0)],
#  ['http://www.hud.gov:80/assist/index.cfm?&lang=en',
#   datetime.datetime(2003, 2, 26, 0, 0),
#   datetime.datetime(2013, 2, 28, 0, 0)],
#  ['http://www.hud.gov:80/assist/privacy.cfm',
#   datetime.datetime(2001, 2, 4, 0, 0),
#   datetime.datetime(2017, 3, 2, 0, 0)],
#  ['http://www.hud.gov:80/assist/privacy.cfm?&lang=en',
#   datetime.datetime(2003, 2, 26, 0, 0),
#   datetime.datetime(2013, 3, 2, 0, 0)],
#  ['http://www.hud.gov:80/assist/service.cfm?&lang=en',
#   datetime.datetime(2003, 2, 26, 0, 0),
#   datetime.datetime(2013, 2, 28, 0, 0)],
#  ['http://www.hud.gov:80/assist/siteindex.cfm',
#   datetime.datetime(2001, 2, 4, 0, 0),
#   datetime.datetime(2019, 6, 7, 0, 0)],
#  ['http://www.hud.gov:80/assist/siteindex.cfm/top',
#   datetime.datetime(2001, 11, 9, 0, 0),
#   datetime.datetime(2019, 1, 16, 0, 0)],
#  ['http://www.hud.gov:80/assist/siteindex.cfm?&lang=en',
#   datetime.datetime(2003, 2, 26, 0, 0),
#   datetime.datetime(2013, 2, 22, 0, 0)],
#  ['http://www.hud.gov:80/assist/sitemap.cfm',
#   datetime.datetime(2009, 11, 7, 0, 0),
#   datetime.datetime(2017, 1, 25, 0, 0)],
#  ['http://www.hud.gov:80/basic.cfm',
#   datetime.datetime(2001, 7, 15, 0, 0),
#   datetime.datetime(2019, 4, 28, 0, 0)],
#  ['http://www.hud.gov:80/bdfy2000/summary/pdandr/randt.cfm',
#   datetime.datetime(2001, 7, 15, 0, 0),
#   datetime.datetime(2018, 6, 9, 0, 0)],
#  ['http://www.hud.gov:80/bfields.html',
#   datetime.datetime(1998, 12, 5, 0, 0),
#   datetime.datetime(2017, 2, 3, 0, 0)],
#  ['http://www.hud.gov:80/budget.html',
#   datetime.datetime(1999, 5, 8, 0, 0),
#   datetime.datetime(2017, 1, 18, 0, 0)],
#  ['http://www.hud.gov:80/budget01/justif/cpd/rc.cfm',
#   datetime.datetime(2001, 7, 15, 0, 0),
#   datetime.datetime(2017, 1, 18, 0, 0)],
#  ['http://www.hud.gov:80/buying/',
#   datetime.datetime(2001, 1, 25, 0, 0),
#   datetime.datetime(2019, 7, 20, 0, 0)],
#  ['http://www.hud.gov:80/buying/buyhudhm.cfm',
#   datetime.datetime(2001, 1, 25, 0, 0),
#   datetime.datetime(2015, 2, 9, 0, 0)],
#  ['http://www.hud.gov:80/buying/comq.cfm',
#   datetime.datetime(2001, 2, 1, 0, 0),
#   datetime.datetime(2019, 7, 11, 0, 0)],
#  ['http://www.hud.gov:80/buying/index.cfm',
#   datetime.datetime(2001, 2, 4, 0, 0),
#   datetime.datetime(2019, 2, 5, 0, 0)],
#  ['http://www.hud.gov:80/buying/index.cfm?&lang=en',
#   datetime.datetime(2003, 6, 5, 0, 0),
#   datetime.datetime(2013, 2, 22, 0, 0)],
#  ['http://www.hud.gov:80/buying/insured.cfm',
#   datetime.datetime(2001, 12, 13, 0, 0),
#   datetime.datetime(2019, 2, 4, 0, 0)],
#  ['http://www.hud.gov:80/buying/localbuying.cfm',
#   datetime.datetime(2002, 10, 6, 0, 0),
#   datetime.datetime(2019, 4, 28, 0, 0)],
#  ['http://www.hud.gov:80/buying/localbuying.cfm?&lang=en',
#   datetime.datetime(2003, 5, 14, 0, 0),
#   datetime.datetime(2013, 3, 26, 0, 0)],
#  ['http://www.hud.gov:80/buying/localbuying.cfm?lang=en',
#   datetime.datetime(2002, 12, 21, 0, 0),
#   datetime.datetime(2013, 3, 26, 0, 0)],
#  ['http://www.hud.gov:80/buying/localhomebuy.cfm',
#   datetime.datetime(2001, 2, 8, 0, 0),
#   datetime.datetime(2015, 3, 14, 0, 0)],
#  ['http://www.hud.gov:80/buying/localpredlend.cfm',
#   datetime.datetime(2003, 2, 5, 0, 0),
#   datetime.datetime(2018, 8, 31, 0, 0)],
#  ['http://www.hud.gov:80/buying/mortprog.cfm',
#   datetime.datetime(2001, 1, 25, 0, 0),
#   datetime.datetime(2017, 7, 4, 0, 0)],
#  ['http://www.hud.gov:80/buying/morttips.cfm',
#   datetime.datetime(2002, 6, 11, 0, 0),
#   datetime.datetime(2016, 11, 14, 0, 0)],
#  ['http://www.hud.gov:80/buying/refinance.cfm',
#   datetime.datetime(2001, 2, 1, 0, 0),
#   datetime.datetime(2018, 1, 10, 0, 0)],
#  ['http://www.hud.gov:80/buying/reverse.cfm',
#   datetime.datetime(2001, 3, 3, 0, 0),
#   datetime.datetime(2017, 12, 6, 0, 0)],
#  ['http://www.hud.gov:80/buying/rvrsmort.cfm',
#   datetime.datetime(2001, 4, 17, 0, 0),
#   datetime.datetime(2019, 1, 24, 0, 0)],
#  ['http://www.hud.gov:80/buying/terms_eng-sp.cfm',
#   datetime.datetime(2001, 11, 7, 0, 0),
#   datetime.datetime(2018, 11, 21, 0, 0)],
#  ['http://www.hud.gov:80/calculator',
#   datetime.datetime(2010, 1, 16, 0, 0),
#   datetime.datetime(2015, 10, 9, 0, 0)],
#  ['http://www.hud.gov:80/calendar/',
#   datetime.datetime(2001, 2, 20, 0, 0),
#   datetime.datetime(2016, 12, 30, 0, 0)],
#  ['http://www.hud.gov:80/calendar/index.cfm',
#   datetime.datetime(2001, 2, 4, 0, 0),
#   datetime.datetime(2015, 8, 21, 0, 0)],
#  ['http://www.hud.gov:80/cb/cbmainmn.html',
#   datetime.datetime(1998, 12, 5, 0, 0),
#   datetime.datetime(2017, 4, 1, 0, 0)],
#  ['http://www.hud.gov:80/cdbg',
#   datetime.datetime(2015, 7, 31, 0, 0),
#   datetime.datetime(2017, 10, 30, 0, 0)],
#  ['http://www.hud.gov:80/cfda/2001/14168.cfm',
#   datetime.datetime(2001, 7, 15, 0, 0),
#   datetime.datetime(2019, 2, 15, 0, 0)],
#  ['http://www.hud.gov:80/cfo/cfoacc96.html',
#   datetime.datetime(1999, 4, 20, 0, 0),
#   datetime.datetime(2017, 2, 18, 0, 0)],
#  ['http://www.hud.gov:80/cio/ciohome.html',
#   datetime.datetime(2000, 3, 3, 0, 0),
#   datetime.datetime(2017, 9, 16, 0, 0)],
#  ['http://www.hud.gov:80/cio/year2000',
#   datetime.datetime(1998, 12, 6, 0, 0),
#   datetime.datetime(2016, 12, 19, 0, 0)],
#  ['http://www.hud.gov:80/cn',
#   datetime.datetime(2010, 9, 1, 0, 0),
#   datetime.datetime(2019, 8, 5, 0, 0)],
#  ['http://www.hud.gov:80/codetalk',
#   datetime.datetime(2005, 4, 4, 0, 0),
#   datetime.datetime(2018, 3, 6, 0, 0)],
#  ['http://www.hud.gov:80/codtctrs.html',
#   datetime.datetime(1998, 2, 9, 0, 0),
#   datetime.datetime(2013, 12, 14, 0, 0)],
#  ['http://www.hud.gov:80/community/',
#   datetime.datetime(2001, 1, 25, 0, 0),
#   datetime.datetime(2015, 9, 18, 0, 0)],
#  ['http://www.hud.gov:80/community/index.cfm',
#   datetime.datetime(2002, 1, 4, 0, 0),
#   datetime.datetime(2017, 1, 15, 0, 0)],
#  ['http://www.hud.gov:80/community/index.cfm?&lang=en',
#   datetime.datetime(2003, 4, 16, 0, 0),
#   datetime.datetime(2013, 2, 27, 0, 0)],
#  ['http://www.hud.gov:80/community/orcomm.html',
#   datetime.datetime(2001, 11, 23, 0, 0),
#   datetime.datetime(2017, 4, 7, 0, 0)],
#  ['http://www.hud.gov:80/community/yourcommunity.cfm',
#   datetime.datetime(2003, 12, 21, 0, 0),
#   datetime.datetime(2013, 2, 20, 0, 0)],
#  ['http://www.hud.gov:80/complaints',
#   datetime.datetime(2001, 3, 21, 0, 0),
#   datetime.datetime(2019, 7, 26, 0, 0)],
#  ['http://www.hud.gov:80/complaints/badlandlord.cfm',
#   datetime.datetime(2001, 2, 10, 0, 0),
#   datetime.datetime(2017, 1, 31, 0, 0)],
#  ['http://www.hud.gov:80/complaints/custservice.cfm',
#   datetime.datetime(2009, 12, 13, 0, 0),
#   datetime.datetime(2018, 12, 31, 0, 0)],
#  ['http://www.hud.gov:80/complaints/decpcontract.cfm',
#   datetime.datetime(2001, 2, 10, 0, 0),
#   datetime.datetime(2019, 2, 3, 0, 0)],
#  ['http://www.hud.gov:80/complaints/fraud_waste.cfm',
#   datetime.datetime(2001, 2, 10, 0, 0),
#   datetime.datetime(2019, 7, 1, 0, 0)],
#  ['http://www.hud.gov:80/complaints/housediscrim.cfm',
#   datetime.datetime(2001, 4, 10, 0, 0),
#   datetime.datetime(2019, 8, 13, 0, 0)],
#  ['http://www.hud.gov:80/complaints/index.cfm',
#   datetime.datetime(2001, 2, 4, 0, 0),
#   datetime.datetime(2016, 12, 20, 0, 0)],
#  ['http://www.hud.gov:80/complaints/index.cfm?&lang=en',
#   datetime.datetime(2003, 4, 16, 0, 0),
#   datetime.datetime(2013, 2, 28, 0, 0)],
#  ['http://www.hud.gov:80/complaints/index.cfm?lang=en',
#   datetime.datetime(2002, 4, 21, 0, 0),
#   datetime.datetime(2016, 7, 1, 0, 0)],
#  ['http://www.hud.gov:80/complaints/landsales.cfm',
#   datetime.datetime(2001, 2, 10, 0, 0),
#   datetime.datetime(2017, 10, 27, 0, 0)],
#  ['http://www.hud.gov:80/complaints/manhousing.cfm',
#   datetime.datetime(2001, 4, 13, 0, 0),
#   datetime.datetime(2017, 9, 10, 0, 0)],
#  ['http://www.hud.gov:80/comq.html',
#   datetime.datetime(1999, 5, 8, 0, 0),
#   datetime.datetime(2019, 1, 19, 0, 0)],
#  ['http://www.hud.gov:80/consum.cfm',
#   datetime.datetime(2001, 1, 25, 0, 0),
#   datetime.datetime(2017, 8, 14, 0, 0)],
#  ['http://www.hud.gov:80/consumer/',
#   datetime.datetime(2001, 2, 8, 0, 0),
#   datetime.datetime(2019, 4, 13, 0, 0)],
#  ['http://www.hud.gov:80/consumer/index.cfm',
#   datetime.datetime(2001, 4, 13, 0, 0),
#   datetime.datetime(2019, 6, 9, 0, 0)],
#  ['http://www.hud.gov:80/consumer/index.cfm?&lang=en',
#   datetime.datetime(2003, 4, 4, 0, 0),
#   datetime.datetime(2013, 2, 27, 0, 0)],
#  ['http://www.hud.gov:80/consumer/local.cfm',
#   datetime.datetime(2003, 2, 22, 0, 0),
#   datetime.datetime(2019, 7, 22, 0, 0)],
#  ['http://www.hud.gov:80/content/releases',
#   datetime.datetime(2009, 7, 18, 0, 0),
#   datetime.datetime(2014, 10, 24, 0, 0)],
#  ['http://www.hud.gov:80/counseling/501',
#   datetime.datetime(2012, 8, 16, 0, 0),
#   datetime.datetime(2013, 4, 10, 0, 0)],
#  ['http://www.hud.gov:80/counselors',
#   datetime.datetime(2010, 3, 29, 0, 0),
#   datetime.datetime(2016, 10, 6, 0, 0)],
#  ['http://www.hud.gov:80/cpd/2020soft.html',
#   datetime.datetime(1997, 12, 12, 0, 0),
#   datetime.datetime(2018, 10, 31, 0, 0)],
#  ['http://www.hud.gov:80/cpd/c2020/mapgal.html',
#   datetime.datetime(2000, 4, 17, 0, 0),
#   datetime.datetime(2016, 3, 10, 0, 0)],
#  ['http://www.hud.gov:80/cpd/colonias.html',
#   datetime.datetime(1999, 2, 9, 0, 0),
#   datetime.datetime(2019, 6, 23, 0, 0)],
#  ['http://www.hud.gov:80/cpd/cpd/cpdprog.html',
#   datetime.datetime(2000, 8, 15, 0, 0),
#   datetime.datetime(2017, 12, 3, 0, 0)],
#  ['http://www.hud.gov:80/cpd/cpdenvir.html',
#   datetime.datetime(1998, 2, 9, 0, 0),
#   datetime.datetime(2013, 2, 22, 0, 0)],
#  ['http://www.hud.gov:80/cpd/cpdhome.html',
#   datetime.datetime(1998, 2, 9, 0, 0),
#   datetime.datetime(2019, 6, 17, 0, 0)],
#  ['http://www.hud.gov:80/cpd/cps/cpsqsas.html',
#   datetime.datetime(2002, 6, 25, 0, 0),
#   datetime.datetime(2018, 12, 21, 0, 0)],
#  ['http://www.hud.gov:80/cpd/econdev/ythhome.html',
#   datetime.datetime(2000, 3, 12, 0, 0),
#   datetime.datetime(2017, 12, 3, 0, 0)],
#  ['http://www.hud.gov:80/cpd/ezec/ceb.html',
#   datetime.datetime(2000, 8, 15, 0, 0),
#   datetime.datetime(2015, 7, 13, 0, 0)],
#  ['http://www.hud.gov:80/cpd/home/homefront/M2/M2T0-00.html',
#   datetime.datetime(2000, 8, 24, 0, 0),
#   datetime.datetime(2017, 8, 31, 0, 0)],
#  ['http://www.hud.gov:80/cpd/home/homeweb.html',
#   datetime.datetime(1999, 10, 10, 0, 0),
#   datetime.datetime(2017, 12, 3, 0, 0)],
#  ['http://www.hud.gov:80/cpd/home/pubindex/notices.html',
#   datetime.datetime(2000, 12, 1, 0, 0),
#   datetime.datetime(2013, 8, 12, 0, 0)],
#  ['http://www.hud.gov:80/cpd/hopwahom.html',
#   datetime.datetime(1998, 12, 6, 0, 0),
#   datetime.datetime(2019, 7, 12, 0, 0)],
#  ['http://www.hud.gov:80/cpd/idis/refman/ref_man_15.pdf',
#   datetime.datetime(2007, 1, 5, 0, 0),
#   datetime.datetime(2017, 2, 23, 0, 0)],
#  ['http://www.hud.gov:80/cpd/ocv/envregul.html',
#   datetime.datetime(2000, 8, 16, 0, 0),
#   datetime.datetime(2013, 3, 3, 0, 0)],
#  ['http://www.hud.gov:80/cpd/oed/funding.html',
#   datetime.datetime(2001, 2, 6, 0, 0),
#   datetime.datetime(2016, 11, 19, 0, 0)],
#  ['http://www.hud.gov:80/cpd/oed/programs.html',
#   datetime.datetime(2001, 3, 29, 0, 0),
#   datetime.datetime(2016, 11, 19, 0, 0)],
#  ['http://www.hud.gov:80/cpd/s+c.html',
#   datetime.datetime(2000, 3, 4, 0, 0),
#   datetime.datetime(2014, 10, 14, 0, 0)],
#  ['http://www.hud.gov:80/cpd/statecon.html',
#   datetime.datetime(1998, 2, 9, 0, 0),
#   datetime.datetime(2013, 7, 13, 0, 0)],
#  ['http://www.hud.gov:80/cr',
#   datetime.datetime(2003, 10, 3, 0, 0),
#   datetime.datetime(2017, 12, 3, 0, 0)],
#  ['http://www.hud.gov:80/crlocator',
#   datetime.datetime(2004, 2, 6, 0, 0),
#   datetime.datetime(2017, 12, 3, 0, 0)],
#  ['http://www.hud.gov:80/cts/osdbu.html',
#   datetime.datetime(1998, 12, 2, 0, 0),
#   datetime.datetime(2017, 9, 16, 0, 0)],
#  ['http://www.hud.gov:80/cuomo.cfm',
#   datetime.datetime(2001, 2, 7, 0, 0),
#   datetime.datetime(2018, 8, 31, 0, 0)],
#  ['http://www.hud.gov:80/datamap',
#   datetime.datetime(2010, 11, 25, 0, 0),
# ...
#   datetime.datetime(2019, 8, 1, 0, 0)],
#  ['http://www.hud.gov:80/groups/appraisers.cfm',
#   datetime.datetime(2001, 2, 5, 0, 0),
#   datetime.datetime(2019, 1, 3, 0, 0)],
#  ['http://www.hud.gov:80/groups/appraisers.cfm?&lang=en',
#   datetime.datetime(2003, 4, 14, 0, 0),
#   datetime.datetime(2013, 3, 1, 0, 0)],
#  ['http://www.hud.gov:80/groups/appraisers.cfm?lang=en',
#   datetime.datetime(2002, 6, 1, 0, 0),
#   datetime.datetime(2016, 11, 18, 0, 0)],
#  ['http://www.hud.gov:80/groups/brokers.cfm',
#   datetime.datetime(2001, 2, 2, 0, 0),
#   datetime.datetime(2016, 10, 5, 0, 0)],
#  ['http://www.hud.gov:80/groups/brokers.cfm?&lang=en',
#   datetime.datetime(2003, 6, 22, 0, 0),
#   datetime.datetime(2013, 3, 1, 0, 0)],
#  ['http://www.hud.gov:80/groups/disabilities.cfm',
#   datetime.datetime(2001, 2, 2, 0, 0),
#   datetime.datetime(2019, 2, 11, 0, 0)],
#  ['http://www.hud.gov:80/groups/disabilities.cfm?&lang=en',
#   datetime.datetime(2003, 8, 4, 0, 0),
#   datetime.datetime(2013, 3, 1, 0, 0)],
#  ['http://www.hud.gov:80/groups/fairhousing.cfm',
#   datetime.datetime(2001, 2, 2, 0, 0),
#   datetime.datetime(2019, 2, 26, 0, 0)],
#  ['http://www.hud.gov:80/groups/fairhousing.cfm?&lang=en',
#   datetime.datetime(2003, 6, 8, 0, 0),
#   datetime.datetime(2013, 3, 2, 0, 0)],
#  ['http://www.hud.gov:80/groups/grantees.cfm',
#   datetime.datetime(2001, 2, 2, 0, 0),
#   datetime.datetime(2019, 3, 29, 0, 0)],
#  ['http://www.hud.gov:80/groups/grantees.cfm?&lang=en',
#   datetime.datetime(2003, 4, 14, 0, 0),
#   datetime.datetime(2013, 3, 1, 0, 0)],
#  ['http://www.hud.gov:80/groups/healthcare.cfm',
#   datetime.datetime(2001, 2, 2, 0, 0),
#   datetime.datetime(2019, 7, 12, 0, 0)],
#  ['http://www.hud.gov:80/groups/investors.cfm?&lang=en',
#   datetime.datetime(2003, 12, 8, 0, 0),
#   datetime.datetime(2013, 3, 2, 0, 0)],
#  ['http://www.hud.gov:80/groups/landlords.cfm',
#   datetime.datetime(2001, 2, 2, 0, 0),
#   datetime.datetime(2019, 1, 15, 0, 0)],
#  ['http://www.hud.gov:80/groups/landlords.cfm?&lang=en',
#   datetime.datetime(2003, 4, 14, 0, 0),
#   datetime.datetime(2013, 3, 1, 0, 0)],
#  ['http://www.hud.gov:80/groups/legal.cfm',
#   datetime.datetime(2004, 6, 23, 0, 0),
#   datetime.datetime(2013, 3, 1, 0, 0)],
#  ['http://www.hud.gov:80/groups/lenders.cfm',
#   datetime.datetime(2001, 1, 25, 0, 0),
#   datetime.datetime(2019, 6, 19, 0, 0)],
#  ['http://www.hud.gov:80/groups/lenders.cfm?&lang=en',
#   datetime.datetime(2003, 4, 14, 0, 0),
#   datetime.datetime(2013, 3, 1, 0, 0)],
#  ['http://www.hud.gov:80/groups/localhomerepair.cfm',
#   datetime.datetime(2006, 8, 19, 0, 0),
#   datetime.datetime(2013, 3, 1, 0, 0)],
#  ['http://www.hud.gov:80/groups/multifamily.cfm',
#   datetime.datetime(2001, 2, 2, 0, 0),
#   datetime.datetime(2019, 6, 19, 0, 0)],
#  ['http://www.hud.gov:80/groups/multifamily.cfm?&lang=en',
#   datetime.datetime(2003, 4, 14, 0, 0),
#   datetime.datetime(2013, 3, 1, 0, 0)],
#  ['http://www.hud.gov:80/groups/nativeamericans.cfm',
#   datetime.datetime(2001, 2, 2, 0, 0),
#   datetime.datetime(2018, 12, 3, 0, 0)],
#  ['http://www.hud.gov:80/groups/nativeamericans.cfm/?&lang=en',
#   datetime.datetime(2003, 5, 24, 0, 0),
#   datetime.datetime(2013, 3, 1, 0, 0)],
#  ['http://www.hud.gov:80/groups/officials.cfm?&lang=en',
#   datetime.datetime(2003, 4, 13, 0, 0),
#   datetime.datetime(2013, 3, 2, 0, 0)],
#  ['http://www.hud.gov:80/groups/phastribes.cfm',
#   datetime.datetime(2001, 1, 25, 0, 0),
#   datetime.datetime(2017, 10, 1, 0, 0)],
#  ['http://www.hud.gov:80/groups/phastribes.cfm?&lang=en',
#   datetime.datetime(2003, 6, 20, 0, 0),
#   datetime.datetime(2013, 3, 1, 0, 0)],
#  ['http://www.hud.gov:80/groups/seniors.cfm',
#   datetime.datetime(2001, 6, 14, 0, 0),
#   datetime.datetime(2019, 2, 13, 0, 0)],
#  ['http://www.hud.gov:80/groups/seniors.cfm?&lang=en',
#   datetime.datetime(2003, 4, 14, 0, 0),
#   datetime.datetime(2013, 3, 1, 0, 0)],
#  ['http://www.hud.gov:80/groups/smallbusiness.cfm',
#   datetime.datetime(2001, 2, 2, 0, 0),
#   datetime.datetime(2018, 9, 9, 0, 0)],
#  ['http://www.hud.gov:80/groups/students.cfm',
#   datetime.datetime(2001, 2, 2, 0, 0),
#   datetime.datetime(2014, 8, 16, 0, 0)],
#  ['http://www.hud.gov:80/groups/students.cfm?&lang=en',
#   datetime.datetime(2003, 4, 13, 0, 0),
#   datetime.datetime(2013, 3, 1, 0, 0)],
#  ['http://www.hud.gov:80/groups/tenants.cfm',
#   datetime.datetime(2001, 2, 2, 0, 0),
#   datetime.datetime(2018, 12, 4, 0, 0)],
#  ['http://www.hud.gov:80/groups/tenants.cfm?&lang=en',
#   datetime.datetime(2003, 4, 13, 0, 0),
#   datetime.datetime(2013, 3, 1, 0, 0)],
#  ['http://www.hud.gov:80/gse',
#   datetime.datetime(2000, 4, 8, 0, 0),
#   datetime.datetime(2017, 1, 18, 0, 0)],
#  ['http://www.hud.gov:80/hawaii',
#   datetime.datetime(2003, 7, 11, 0, 0),
#   datetime.datetime(2016, 4, 4, 0, 0)],
#  ['http://www.hud.gov:80/hdiscrim.html',
#   datetime.datetime(1998, 2, 9, 0, 0),
#   datetime.datetime(2019, 1, 20, 0, 0)],
#  ['http://www.hud.gov:80/healthcare',
#   datetime.datetime(2012, 7, 26, 0, 0),
#   datetime.datetime(2017, 12, 3, 0, 0)],
#  ['http://www.hud.gov:80/healthy/index.cfm',
#   datetime.datetime(2001, 12, 20, 0, 0),
#   datetime.datetime(2017, 9, 24, 0, 0)],
#  ['http://www.hud.gov:80/healthy/mainmenu.html',
#   datetime.datetime(1999, 4, 21, 0, 0),
#   datetime.datetime(2019, 8, 1, 0, 0)],
#  ['http://www.hud.gov:80/healthy/safehome.html',
#   datetime.datetime(1999, 1, 28, 0, 0),
#   datetime.datetime(2013, 12, 19, 0, 0)],
#  ['http://www.hud.gov:80/healthyhomes',
#   datetime.datetime(2004, 4, 21, 0, 0),
#   datetime.datetime(2019, 6, 29, 0, 0)],
#  ['http://www.hud.gov:80/hhchild.html',
#   datetime.datetime(1999, 1, 28, 0, 0),
#   datetime.datetime(2017, 12, 3, 0, 0)],
#  ['http://www.hud.gov:80/hoc/sna/snanfpap.html',
#   datetime.datetime(1999, 5, 7, 0, 0),
#   datetime.datetime(2016, 12, 30, 0, 0)],
#  ['http://www.hud.gov:80/hoc/sna/snatftht.html',
#   datetime.datetime(1999, 2, 24, 0, 0),
#   datetime.datetime(2017, 11, 6, 0, 0)],
#  ['http://www.hud.gov:80/homeless',
#   datetime.datetime(2002, 4, 18, 0, 0),
#   datetime.datetime(2019, 7, 10, 0, 0)],
#  ['http://www.hud.gov:80/homeless/definition.cfm',
#   datetime.datetime(2007, 10, 22, 0, 0),
#   datetime.datetime(2019, 3, 27, 0, 0)],
#  ['http://www.hud.gov:80/homeless/fedprog.cfm',
#   datetime.datetime(2001, 6, 24, 0, 0),
#   datetime.datetime(2019, 1, 8, 0, 0)],
#  ['http://www.hud.gov:80/homeless/hmasist1.cfm',
#   datetime.datetime(2002, 4, 16, 0, 0),
#   datetime.datetime(2015, 9, 19, 0, 0)],
#  ['http://www.hud.gov:80/homeless/hmlsagen.cfm',
#   datetime.datetime(2002, 3, 21, 0, 0),
#   datetime.datetime(2018, 3, 12, 0, 0)],
#  ['http://www.hud.gov:80/homeless/index.cfm',
#   datetime.datetime(2001, 2, 4, 0, 0),
#   datetime.datetime(2019, 1, 12, 0, 0)],
#  ['http://www.hud.gov:80/homeless/index.cfm?&lang=en',
#   datetime.datetime(2003, 4, 16, 0, 0),
#   datetime.datetime(2013, 2, 27, 0, 0)],
#  ['http://www.hud.gov:80/homeless/index.cfm?lang=en',
#   datetime.datetime(2002, 4, 18, 0, 0),
#   datetime.datetime(2017, 2, 25, 0, 0)],
#  ['http://www.hud.gov:80/homelesscount',
#   datetime.datetime(2011, 1, 26, 0, 0),
#   datetime.datetime(2016, 12, 3, 0, 0)],
#  ['http://www.hud.gov:80/homeownership',
#   datetime.datetime(2002, 10, 6, 0, 0),
#   datetime.datetime(2013, 11, 12, 0, 0)],
#  ['http://www.hud.gov:80/homeprogram/',
#   datetime.datetime(2004, 6, 25, 0, 0),
#   datetime.datetime(2017, 9, 8, 0, 0)],
#  ['http://www.hud.gov:80/homes/',
#   datetime.datetime(2001, 1, 27, 0, 0),
#   datetime.datetime(2019, 8, 16, 0, 0)],
#  ['http://www.hud.gov:80/homes/building.cfm',
#   datetime.datetime(2006, 6, 15, 0, 0),
#   datetime.datetime(2018, 8, 24, 0, 0)],
#  ['http://www.hud.gov:80/homes/homesforsale.cfm',
#   datetime.datetime(2001, 2, 5, 0, 0),
#   datetime.datetime(2019, 3, 10, 0, 0)],
#  ['http://www.hud.gov:80/homes/homesforsale.cfm?&lang=en',
#   datetime.datetime(2003, 4, 13, 0, 0),
#   datetime.datetime(2013, 3, 1, 0, 0)],
#  ['http://www.hud.gov:80/homes/index.cfm',
#   datetime.datetime(2001, 1, 25, 0, 0),
#   datetime.datetime(2018, 12, 27, 0, 0)],
#  ['http://www.hud.gov:80/homes/index.cfm?&lang=en',
#   datetime.datetime(2003, 8, 18, 0, 0),
#   datetime.datetime(2013, 2, 27, 0, 0)],
#  ['http://www.hud.gov:80/homes/manufactured.cfm',
#   datetime.datetime(2006, 2, 8, 0, 0),
#   datetime.datetime(2018, 8, 24, 0, 0)],
#  ['http://www.hud.gov:80/hopeforhomeowners/',
#   datetime.datetime(2008, 10, 5, 0, 0),
#   datetime.datetime(2017, 3, 26, 0, 0)],
#  ['http://www.hud.gov:80/hopeforhomeowners/consumerfactsheet.cfm',
#   datetime.datetime(2008, 10, 4, 0, 0),
#   datetime.datetime(2017, 1, 2, 0, 0)],
#  ['http://www.hud.gov:80/hopeforhomeowners/index.cfm',
#   datetime.datetime(2008, 10, 3, 0, 0),
#   datetime.datetime(2019, 3, 6, 0, 0)],
#  ['http://www.hud.gov:80/housingcounseling',
#   datetime.datetime(2015, 1, 2, 0, 0),
#   datetime.datetime(2017, 12, 3, 0, 0)],
#  ['http://www.hud.gov:80/hudclips',
#   datetime.datetime(2008, 1, 9, 0, 0),
#   datetime.datetime(2019, 6, 8, 0, 0)],
#  ['http://www.hud.gov:80/hudvet/',
#   datetime.datetime(1999, 2, 23, 0, 0),
#   datetime.datetime(2017, 9, 25, 0, 0)],
#  ['http://www.hud.gov:80/idaho',
#   datetime.datetime(2003, 2, 24, 0, 0),
#   datetime.datetime(2015, 9, 25, 0, 0)],
#  ['http://www2.hud.gov:80/cdc.html',
#   datetime.datetime(1998, 12, 5, 0, 0),
#   datetime.datetime(2019, 7, 12, 0, 0)],
#  ['http://www2.hud.gov:80/enforce/ecindex.html',
#   datetime.datetime(1998, 12, 3, 0, 0),
#   datetime.datetime(2017, 9, 16, 0, 0)],
#  ['http://www2.hud.gov:80/gpra/gnma.html',
#   datetime.datetime(1999, 2, 20, 0, 0),
#   datetime.datetime(2014, 9, 28, 0, 0)],
#  ['http://www2.hud.gov:80/gpra/ogc.html',
#   datetime.datetime(1999, 2, 20, 0, 0),
#   datetime.datetime(2015, 8, 1, 0, 0)],
#  ['https://www.hud.gov/emarc/index.cfm?fuseaction=emar.registrationNotOpenError&eventid=1177',
#   datetime.datetime(2017, 1, 1, 0, 0),
#   datetime.datetime(2017, 1, 1, 0, 0)],
#  ['https://www11.hud.gov/HUD_Systems',
#   datetime.datetime(2005, 9, 7, 0, 0),
#   datetime.datetime(2015, 6, 26, 0, 0)],
#  ['https://www11.hud.gov/HUD_Systems/index.cfm',
#   datetime.datetime(2005, 9, 7, 0, 0),
#   datetime.datetime(2013, 2, 20, 0, 0)],
#  ['https://www21.hud.gov/idis',
#   datetime.datetime(2010, 5, 27, 0, 0),
#   datetime.datetime(2013, 9, 14, 0, 0)],
#  ['https://www5.hud.gov/Ecomplaints',
#   datetime.datetime(2010, 5, 27, 0, 0),
#   datetime.datetime(2015, 9, 26, 0, 0)],
#  ['https://www5.hud.gov/Ecomplaints/Logins/PagLogin.jsp',
#   datetime.datetime(2010, 5, 27, 0, 0),
#   datetime.datetime(2015, 9, 27, 0, 0)],
#  ['https://www5.hud.gov/ecpcis',
#   datetime.datetime(2010, 5, 27, 0, 0),
#   datetime.datetime(2019, 1, 11, 0, 0)],
#  ['https://www5.hud.gov/ecpcis/index.jsp',
#   datetime.datetime(2010, 5, 27, 0, 0),
#   datetime.datetime(2015, 9, 7, 0, 0)],
#  ['https://www5.hud.gov/Ecpcis/main/ECPCIS_List',
#   datetime.datetime(2006, 9, 26, 0, 0),
#   datetime.datetime(2019, 4, 26, 0, 0)],
#  ['https://www5.hud.gov/ecpcis/main/ECPCIS_List.jsp',
#   datetime.datetime(2010, 5, 27, 0, 0),
#   datetime.datetime(2019, 1, 9, 0, 0)],
#  ['https://www5.hud.gov/Ecpcis/main/ECPCIS_List/index.jsp',
#   datetime.datetime(2017, 1, 17, 0, 0),
#   datetime.datetime(2017, 1, 30, 0, 0)],
#  ['https://www5.hud.gov/Ecpcis/main/ECPCIS_List/main/ECPCIS_List.jsp',
#   datetime.datetime(2017, 1, 17, 0, 0),
#   datetime.datetime(2019, 1, 11, 0, 0)],
#  ['https://www5.hud.gov/Ecpcis/main/ECPCIS_List/main/Help.html',
#   datetime.datetime(2017, 1, 17, 0, 0),
#   datetime.datetime(2017, 1, 17, 0, 0)],
#  ['https://www5.hud.gov/ecpcis/main/Help.html',
#   datetime.datetime(2010, 5, 27, 0, 0),
#   datetime.datetime(2016, 11, 28, 0, 0)],
#  ['https://www5.hud.gov/FHALender/',
#   datetime.datetime(2013, 3, 16, 0, 0),
#   datetime.datetime(2017, 1, 30, 0, 0)],
#  ['https://www5.hud.gov/FHALender/fhalogin.jsp',
#   datetime.datetime(2013, 3, 16, 0, 0),
#   datetime.datetime(2015, 9, 6, 0, 0)],
#  ['https://www5.hud.gov/FHALender/FHAStore',
#   datetime.datetime(2013, 3, 16, 0, 0),
#   datetime.datetime(2013, 3, 16, 0, 0)],
#  ['https://www5.hud.gov/FHALender/FHAUploadServlet',
#   datetime.datetime(2013, 3, 16, 0, 0),
#   datetime.datetime(2013, 3, 16, 0, 0)],
#  ['https://www5.hud.gov/FHALender/Online/page_address.jsp',
#   datetime.datetime(2013, 3, 16, 0, 0),
#   datetime.datetime(2013, 3, 16, 0, 0)],
#  ['https://www5.hud.gov/FHALender/Online/page_address.jsp?edit=1',
#   datetime.datetime(2013, 3, 16, 0, 0),
#   datetime.datetime(2013, 3, 16, 0, 0)],
#  ['https://www5.hud.gov/FHALender/Online/page_already_registered_question.jsp',
#   datetime.datetime(2013, 3, 16, 0, 0),
#   datetime.datetime(2013, 3, 16, 0, 0)],
#  ['https://www5.hud.gov/FHALender/Online/page_certification.jsp',
#   datetime.datetime(2013, 3, 16, 0, 0),
#   datetime.datetime(2013, 3, 16, 0, 0)],
#  ['https://www5.hud.gov/FHALender/Online/page_contacts.jsp',
#   datetime.datetime(2013, 3, 16, 0, 0),
#   datetime.datetime(2013, 3, 16, 0, 0)],
#  ['https://www5.hud.gov/FHALender/Online/page_contacts.jsp?edit=1',
#   datetime.datetime(2013, 3, 16, 0, 0),
#   datetime.datetime(2013, 3, 16, 0, 0)],
#  ['https://www5.hud.gov/FHALender/Online/page_conversion.jsp',
#   datetime.datetime(2013, 3, 16, 0, 0),
#   datetime.datetime(2013, 3, 16, 0, 0)],
#  ['https://www5.hud.gov/FHALender/Online/page_conversion.jsp?edit=1',
#   datetime.datetime(2013, 3, 16, 0, 0),
#   datetime.datetime(2013, 3, 16, 0, 0)],
#  ['https://www5.hud.gov/FHALender/Online/page_conversion_upload.jsp',
#   datetime.datetime(2013, 3, 16, 0, 0),
#   datetime.datetime(2013, 3, 16, 0, 0)],
#  ['https://www5.hud.gov/FHALender/Online/page_general_info.jsp',
#   datetime.datetime(2013, 3, 16, 0, 0),
#   datetime.datetime(2013, 3, 16, 0, 0)],
#  ['https://www5.hud.gov/FHALender/Online/page_general_info.jsp?edit=1',
#   datetime.datetime(2013, 3, 16, 0, 0),
#   datetime.datetime(2013, 3, 16, 0, 0)],
#  ['https://www5.hud.gov/FHALender/Online/page_history_business_status.jsp',
#   datetime.datetime(2013, 3, 16, 0, 0),
#   datetime.datetime(2013, 3, 16, 0, 0)],
#  ['https://www5.hud.gov/FHALender/Online/page_history_business_status.jsp?edit=1',
#   datetime.datetime(2013, 3, 16, 0, 0),
#   datetime.datetime(2013, 3, 16, 0, 0)],
#  ['https://www5.hud.gov/FHALender/Online/page_individual.jsp',
#   datetime.datetime(2013, 3, 16, 0, 0),
#   datetime.datetime(2013, 3, 16, 0, 0)],
#  ['https://www5.hud.gov/FHALender/Online/page_individual.jsp?edit=1',
#   datetime.datetime(2013, 3, 16, 0, 0),
#   datetime.datetime(2013, 3, 16, 0, 0)],
#  ['https://www5.hud.gov/FHALender/Online/page_initial_type.jsp',
#   datetime.datetime(2013, 3, 16, 0, 0),
#   datetime.datetime(2013, 3, 16, 0, 0)],
#  ['https://www5.hud.gov/FHALender/Online/page_items_to_submit.jsp',
#   datetime.datetime(2013, 3, 16, 0, 0),
#   datetime.datetime(2013, 3, 16, 0, 0)],
#  ['https://www5.hud.gov/FHALender/Online/page_items_to_submit.jsp?edit=1',
#   datetime.datetime(2013, 3, 16, 0, 0),
#   datetime.datetime(2013, 3, 16, 0, 0)],
#  ['https://www5.hud.gov/FHALender/Online/page_login.jsp',
#   datetime.datetime(2013, 3, 16, 0, 0),
#   datetime.datetime(2013, 3, 16, 0, 0)],
#  ['https://www5.hud.gov/FHALender/Online/page_logout.jsp',
#   datetime.datetime(2013, 3, 16, 0, 0),
#   datetime.datetime(2013, 3, 16, 0, 0)],
#  ['https://www5.hud.gov/FHALender/Online/page_new_upload.jsp',
#   datetime.datetime(2013, 3, 16, 0, 0),
#   datetime.datetime(2013, 3, 16, 0, 0)],
#  ['https://www5.hud.gov/FHALender/Online/page_new_upload.jsp?edit=1',
#   datetime.datetime(2013, 3, 16, 0, 0),
#   datetime.datetime(2013, 3, 16, 0, 0)],
#  ['https://www5.hud.gov/FHALender/Online/page_officers.jsp',
#   datetime.datetime(2013, 3, 16, 0, 0),
#   datetime.datetime(2013, 3, 16, 0, 0)],
#  ['https://www5.hud.gov/FHALender/Online/page_payment_initial.jsp',
#   datetime.datetime(2013, 3, 16, 0, 0),
#   datetime.datetime(2013, 3, 16, 0, 0)],
#  ['https://www5.hud.gov/FHALender/Online/page_signature.jsp',
#   datetime.datetime(2013, 3, 16, 0, 0),
#   datetime.datetime(2013, 3, 16, 0, 0)],
#  ['https://www5.hud.gov/FHALender/Online/page_summary.jsp',
#   datetime.datetime(2013, 3, 16, 0, 0),
#   datetime.datetime(2013, 3, 16, 0, 0)],
#  ['https://www5.hud.gov/FHALender/Online/page_summary_conversion.jsp',
#   datetime.datetime(2013, 3, 16, 0, 0),
#   datetime.datetime(2013, 3, 16, 0, 0)],
#  ['https://www5.hud.gov/Hud903/main/pagHUD903Form.jsp',
#   datetime.datetime(2009, 1, 17, 0, 0),
#   datetime.datetime(2017, 6, 19, 0, 0)]]

# %%
not_accepted = ['.gif', '.pdf', '.jpg', '.png', 'lang=es', '.ppt', '.doc',
               '.rtf', 'calendar/event']
hud_links = [link[0] for link in stored_copy if not any (element in link for element in not_accepted)]
hud_links
# Out:
# ['http://hud.gov:80/budgetsummary2011/index.cfm',
#  'http://hud.gov:80/data',
#  'http://hud.gov:80/data.json',
#  'http://hud.gov:80/fairhousing%22',
#  'http://hud.gov:80/fathersday2011',
#  'http://www.hud.gov.:80/',
#  'http://www.hud.gov.:80/49mackte.html',
#  'http://www.hud.gov.:80/admshell.html',
#  'http://www.hud.gov.:80/aljshell.html',
#  'http://www.hud.gov.:80/awardny.html',
#  'http://www.hud.gov.:80/bcashell.html',
#  'http://www.hud.gov.:80/broker1.html',
#  'http://www.hud.gov.:80/bshelf4.html',
#  'http://www.hud.gov.:80/bshelf5.html',
#  'http://www.hud.gov.:80/buyhudhm.html',
#  'http://www.hud.gov.:80/cfo/cfohome.html',
#  'http://www.hud.gov.:80/cirshell.html',
#  'http://www.hud.gov.:80/citizen.html',
#  'http://www.hud.gov.:80/comdev.html',
#  'http://www.hud.gov.:80/commut.html',
#  'http://www.hud.gov.:80/consum.html',
#  'http://www.hud.gov.:80/cpd/',
#  'http://www.hud.gov.:80/cpd/c2020sft.html',
#  'http://www.hud.gov.:80/cpd/cdbg.html',
#  'http://www.hud.gov.:80/cpd/cdbgfct.html',
#  'http://www.hud.gov.:80/cpd/conplan.html',
#  'http://www.hud.gov.:80/cpd/cpdpr95a.html',
#  'http://www.hud.gov.:80/cpd/ezec/',
#  'http://www.hud.gov.:80/cpd/ezec/ezbyez.html',
#  'http://www.hud.gov.:80/cpd/ezec/ezeclist.html',
#  'http://www.hud.gov.:80/cpd/statefct.html',
#  'http://www.hud.gov.:80/cpes/la/shrevela.html',
#  'http://www.hud.gov.:80/cpes/mn/stpaulmn.html',
#  'http://www.hud.gov.:80/cpes/pa/buckscpa.html',
#  'http://www.hud.gov.:80/cts/ctshome.html',
#  'http://www.hud.gov.:80/directory/contents.html',
#  'http://www.hud.gov.:80/disabled.html',
#  'http://www.hud.gov.:80/fairhsg1.html',
#  'http://www.hud.gov.:80/fha/',
#  'http://www.hud.gov.:80/fha/fhahome.html/',
#  'http://www.hud.gov.:80/fha/fhains.html',
#  'http://www.hud.gov.:80/fha/mfh/mfhSec8.html',
#  'http://www.hud.gov.:80/fha/mletters/mltrmenu.html',
#  'http://www.hud.gov.:80/fha/res/respa_hm.html',
#  'http://www.hud.gov.:80/fha/sfh/mhs/mhscnsmr.html',
#  'http://www.hud.gov.:80/fha/sfh/mhs/mhshome.html',
#  'http://www.hud.gov.:80/fha/sfh/mhs/mhsmpsp.html',
#  'http://www.hud.gov.:80/fha/sfh/mhs/mhssaa.html',
#  'http://www.hud.gov.:80/fha/sfh/mhs/mhssht3.html',
#  'http://www.hud.gov.:80/fha/sfh/sfhhomeb.html',
#  'http://www.hud.gov.:80/fhe/fheact.html',
#  'http://www.hud.gov.:80/fhe/fheo.html',
#  'http://www.hud.gov.:80/fhe/fheologo.html',
#  'http://www.hud.gov.:80/fhefhag.html',
#  'http://www.hud.gov.:80/fhegtway.html',
#  'http://www.hud.gov.:80/forms/formwrhs.html',
#  'http://www.hud.gov.:80/fundopp.html',
#  'http://www.hud.gov.:80/govorhs.html',
#  'http://www.hud.gov.:80/hmbuyers.html',
#  'http://www.hud.gov.:80/hmless.html',
#  'http://www.hud.gov.:80/homeless.html',
#  'http://www.hud.gov.:80/homesale.html',
#  'http://www.hud.gov.:80/hudvet/vetfact.html',
#  'http://www.hud.gov.:80/hudvet/vethless.html',
#  'http://www.hud.gov.:80/hudvet/vetmain.html',
#  'http://www.hud.gov.:80/hudvet/vetres.html',
#  'http://www.hud.gov/?adid=www.nubianlink.net',
#  'http://www.hud.gov/?external-link',
#  'http://www.hud.gov/?keepThis=true&TB_iframe=true&height=650&width=850',
#  'http://www.hud.gov/about/staff/dwilliams.cfm',
#  'http://www.hud.gov/about/staff/kgottfried.cfm',
#  'http://www.hud.gov/about/staff/kkendrick.cfm',
#  'http://www.hud.gov/alabama/',
#  'http://www.hud.gov/apps/calendar/event.cfm?state=ak&record=12612&scheduleID=12357&calendarID=5',
#  'http://www.hud.gov/apps/calendar/event.cfm?state=ak&record=12674&scheduleID=12419&calendarID=5',
#  'http://www.hud.gov/apps/calendar/event.cfm?state=ak&record=12680&scheduleID=12425&calendarID=5',
#  'http://www.hud.gov/apps/calendar/event.cfm?state=ak&record=12681&scheduleID=12426&calendarID=5',
#  'http://www.hud.gov/apps/calendar/event.cfm?state=ak&record=12709&scheduleID=12454&calendarID=5',
#  'http://www.hud.gov/apps/calendar/event.cfm?state=ak&record=12759&scheduleID=12504&calendarID=5',
#  'http://www.hud.gov/apps/calendar/event.cfm?state=az&record=12554&scheduleID=12299&calendarID=6',
#  'http://www.hud.gov/apps/calendar/event.cfm?state=az&record=12748&scheduleID=12493&calendarID=6',
#  'http://www.hud.gov/apps/calendar/event.cfm?state=az&record=12756&scheduleID=12501&calendarID=6',
#  'http://www.hud.gov/apps/calendar/event.cfm?state=ca&record=10142&scheduleID=9903&calendarID=8',
#  'http://www.hud.gov/apps/calendar/event.cfm?state=ca&record=12748&scheduleID=12493&calendarID=8',
#  'http://www.hud.gov/apps/calendar/event.cfm?state=ca&record=12749&scheduleID=12494&calendarID=8',
#  'http://www.hud.gov/apps/calendar/event.cfm?state=co&record=12747&scheduleID=12492&calendarID=9',
#  'http://www.hud.gov/apps/calendar/event.cfm?state=co&record=12754&scheduleID=12499&calendarID=9',
#  'http://www.hud.gov/apps/section8/results.cfm?city_name_text=&county_name_text=Harford&zip_code=&property_name_text=&client_group_type=&maxrec=20&state_code=MD&statename=Maryland',
#  'http://www.hud.gov/apps/section8/results.cfm?city_name_text=&county_name_text=SAN+DIEGO&zip_code=&property_name_text=&client_group_type=&maxrec=20&state_code=CA&statename=California&start=101',
#  'http://www.hud.gov/apps/section8/results.cfm?city_name_text=&county_name_text=SAN+DIEGO&zip_code=&property_name_text=&client_group_type=&maxrec=20&state_code=CA&statename=California&start=21',
#  'http://www.hud.gov/apps/section8/results.cfm?city_name_text=&county_name_text=SAN+DIEGO&zip_code=&property_name_text=&client_group_type=&maxrec=20&state_code=CA&statename=California&start=41',
#  'http://www.hud.gov/apps/section8/results.cfm?city_name_text=&county_name_text=SAN+DIEGO&zip_code=&property_name_text=&client_group_type=&maxrec=20&state_code=CA&statename=California&start=61',
#  'http://www.hud.gov/apps/section8/results.cfm?city_name_text=&county_name_text=SAN+DIEGO&zip_code=&property_name_text=&client_group_type=&maxrec=20&state_code=CA&statename=California&start=81',
#  'http://www.hud.gov/apps/section8/step2.cfm?state=CT%2CConnecticut%20',
#  'http://www.hud.gov/apps/section8/step2.cfm?state=KS,%20Kansas',
#  'http://www.hud.gov/apps/section8/step2.cfm?state=MO,%20Missouri',
#  'http://www.hud.gov/apps/section8/step2.cfm?state=NJ%2CNewJersey',
#  'http://www.hud.gov/apps/section8/step2.cfm?state=NM%2CNewMexico',
#  'http://www.hud.gov/apps/section8/step2.cfm?state=PA,%20Pennsylvania%20',
#  'http://www.hud.gov/apps/section8/step2.cfm?state=VA,%20Virginia',
#  'http://www.hud.gov/apps/section8/step2.cfm?state=WV,%20West%20Virginia',
#  'http://www.hud.gov/assist/webpolicies.cfm',
#  'http://www.hud.gov/assist/webpolicies.cfm?&lang=en',
#  'http://www.hud.gov/budgetsummary2010/index.cfm',
#  'http://www.hud.gov/budgetsummary2010/index.cfm?&lang=en',
#  'http://www.hud.gov/buying/loans.cfm',
#  'http://www.hud.gov/california',
#  'http://www.hud.gov/complaints/housediscrim.cfm?&lang=en',
#  'http://www.hud.gov/connecticut',
#  'http://www.hud.gov/counseling',
#  'http://www.hud.gov/cpd/c2020/colonias/ca.jpg',
#  'http://www.hud.gov/cpd/c2020/colonias/nm.jpg',
#  'http://www.hud.gov/cpd/hhpass.gif',
#  'http://www.hud.gov/cpd/home/homeweb.html;MARY_KOLESAR@hud.gov',
#  'http://www.hud.gov/cpd/idis.gif',
#  'http://www.hud.gov/cpd/idis/back.jpg',
#  'http://www.hud.gov/cpd/images/cpd10b.gif',
#  'http://www.hud.gov/digitalstrategy',
#  'http://www.hud.gov/districtofcolumbia',
#  'http://www.hud.gov/emarc/index.cfm',
#  'http://www.hud.gov/emarc/index.cfm?fuseaction=emar.addRegisterEvent&eventId=2153&update=N',
#  'http://www.hud.gov/emarc/index.cfm?fuseaction=emar.addRegisterEvent&eventId=2286&update=N',
#  'http://www.hud.gov/emarc/index.cfm?fuseaction=emar.registerEvent&eventId=1177&update=N',
#  'http://www.hud.gov/emarc/index.cfm?fuseaction=emar.registerEvent&eventId=1241&update=N',
#  'http://www.hud.gov/emarc/index.cfm?fuseaction=emar.registerEvent&eventId=1583&update=N',
#  'http://www.hud.gov/emarc/index.cfm?fuseaction=emar.registerEvent&eventId=1593&update=N',
#  'http://www.hud.gov/emarc/index.cfm?fuseaction=emar.registerEvent&eventId=2009&update=N',
#  'http://www.hud.gov/emarc/index.cfm?fuseaction=emar.registerEvent&eventId=2053&update=N',
#  'http://www.hud.gov/emarc/index.cfm?fuseaction=emar.registerEvent&eventId=2341&update=N',
#  'http://www.hud.gov/emarc/index.cfm?fuseaction=emar.registerEvent&eventId=2348&update=N',
#  'http://www.hud.gov/emarc/index.cfm?fuseaction=emar.registerEvent&eventId=2418&update=N',
#  'http://www.hud.gov/emarc/index.cfm?fuseaction=emar.registerEventSearch',
#  'http://www.hud.gov/emarc/index.cfm?fuseaction=emar.registerEventSearch&pass_submit=1',
#  'http://www.hud.gov/emarc/index.cfm?fuseaction=emar.registrationHome',
#  'http://www.hud.gov/emarc/index.cfm?fuseaction=emar.registrationNotOpenError&eventid=1583',
#  'http://www.hud.gov/emarc/index.cfm?fuseaction=emar.registrationNotOpenError&eventid=1593',
#  'http://www.hud.gov/emarc/index.cfm?fuseaction=emar.registrationNotOpenError&eventid=2153',
#  'http://www.hud.gov/emarc/index.cfm?fuseaction=emar.registrationNotOpenError&eventid=2418',
#  'http://www.hud.gov/emarc/index.cfm?fuseaction=emarc.error&CFID=20892032&CFTOKEN=22613189',
#  'http://www.hud.gov/energystar/developers.cfm',
#  'http://www.hud.gov/energystar/grantees.cfm',
#  'http://www.hud.gov/fha/loans.cfm',
#  'http://www.hud.gov/fhcomplaints',
#  'http://www.hud.gov/findacounselor',
#  'http://www.hud.gov/FOIA',
#  'http://www.hud.gov/foreclosure/index.cfm?&lang=es',
#  'http://www.hud.gov/groups/contacts.cfm',
#  'http://www.hud.gov/groups/farmwkercolonia.cfm',
#  'http://www.hud.gov/groups/funding.cfm',
#  'http://www.hud.gov/groups/hudprograms.cfm',
#  'http://www.hud.gov/groups/library.cfm',
#  'http://www.hud.gov/groups/organization.cfm',
#  'http://www.hud.gov/hudhomes',
#  'http://www.hud.gov:80/232forms',
#  'http://www.hud.gov:80/50',
#  'http://www.hud.gov:80/?NF=1',
#  'http://www.hud.gov:80/?res=1024&ver=true',
#  'http://www.hud.gov:80/?Trade%20Data%20Centerr=www.Tradedc.com',
#  'http://www.hud.gov:80/about/',
#  'http://www.hud.gov:80/about/acronyms.cfm',
#  'http://www.hud.gov:80/about/acronyms.cfm?state=az',
#  'http://www.hud.gov:80/about/hqbuilding.cfm',
#  'http://www.hud.gov:80/about/index.cfm',
#  'http://www.hud.gov:80/about/index.cfm?&lang=en',
#  'http://www.hud.gov:80/about/inventory.cfm/',
#  'http://www.hud.gov:80/about/keyhq.cfm',
#  'http://www.hud.gov:80/about/qaintro.cfm',
#  'http://www.hud.gov:80/about/secretary/',
#  'http://www.hud.gov:80/about/secretary/bernardibio.cfm',
#  'http://www.hud.gov:80/about/secretary/donohuebio.cfm',
#  'http://www.hud.gov:80/about/secretary/donovanbio.cfm',
#  'http://www.hud.gov:80/about/secretary/hudsecy.cfm',
#  'http://www.hud.gov:80/about/secretary/jacksonbio.cfm',
#  'http://www.hud.gov:80/about/secretary/prestonbio.cfm',
#  'http://www.hud.gov:80/about/section8.cfm',
#  'http://www.hud.gov:80/AFFH',
#  'http://www.hud.gov:80/alaska',
#  'http://www.hud.gov:80/answers',
#  'http://www.hud.gov:80/answers.',
#  'http://www.hud.gov:80/anytown/anytown.html',
#  'http://www.hud.gov:80/anytown/map.html',
#  'http://www.hud.gov:80/anytown/police.html',
#  'http://www.hud.gov:80/appraisers/',
#  'http://www.hud.gov:80/apps/section8/',
#  'http://www.hud.gov:80/apps/section8/index.cfm',
#  'http://www.hud.gov:80/apps/section8/index.cfm?CFID=1000762&CFTOKEN=15306169',
#  'http://www.hud.gov:80/apps/section8/results.cfm?city_name_text=&county_name_text=SAN+DIEGO&zip_code=&property_name_text=&client_group_type=&maxrec=20&state_code=CA&statename=California',
#  'http://www.hud.gov:80/apps/section8/step2.cfm?state=AK,Alaska',
#  'http://www.hud.gov:80/apps/section8/step2.cfm?state=AL,Alabama',
#  'http://www.hud.gov:80/apps/section8/step2.cfm?state=AR,Arkansas',
#  'http://www.hud.gov:80/apps/section8/step2.cfm?state=AZ,Arizona',
#  'http://www.hud.gov:80/apps/section8/step2.cfm?state=CA,California',
#  'http://www.hud.gov:80/apps/section8/step2.cfm?state=CO,Colorado',
#  'http://www.hud.gov:80/apps/section8/step2.cfm?state=CT,Connecticut',
#  'http://www.hud.gov:80/apps/section8/step2.cfm?state=DC',
#  'http://www.hud.gov:80/apps/section8/step2.cfm?state=DC,District+of+Columbia',
#  'http://www.hud.gov:80/apps/section8/step2.cfm?state=DE',
#  'http://www.hud.gov:80/apps/section8/step2.cfm?state=DE,Delaware',
#  'http://www.hud.gov:80/apps/section8/step2.cfm?state=FL,Florida',
#  'http://www.hud.gov:80/apps/section8/step2.cfm?state=GA,Georgia',
#  'http://www.hud.gov:80/apps/section8/step2.cfm?state=HI,Hawaii',
#  'http://www.hud.gov:80/apps/section8/step2.cfm?state=IA,Iowa',
#  'http://www.hud.gov:80/apps/section8/step2.cfm?state=ID,Idaho',
#  'http://www.hud.gov:80/apps/section8/step2.cfm?state=IL,Illinois',
#  'http://www.hud.gov:80/apps/section8/step2.cfm?state=IN,Indiana',
#  'http://www.hud.gov:80/apps/section8/step2.cfm?state=KS,Kansas',
#  'http://www.hud.gov:80/apps/section8/step2.cfm?state=KY,Kentucky',
#  'http://www.hud.gov:80/apps/section8/step2.cfm?state=LA,Louisiana',
#  'http://www.hud.gov:80/apps/section8/step2.cfm?state=MA,Massachusetts',
#  'http://www.hud.gov:80/apps/section8/step2.cfm?state=MD',
#  'http://www.hud.gov:80/apps/section8/step2.cfm?state=MD,Maryland',
#  'http://www.hud.gov:80/apps/section8/step2.cfm?state=ME,Maine',
#  'http://www.hud.gov:80/apps/section8/step2.cfm?state=MI,Michigan',
#  'http://www.hud.gov:80/apps/section8/step2.cfm?state=MN,Minnesota',
#  'http://www.hud.gov:80/apps/section8/step2.cfm?state=MO,Missouri',
#  'http://www.hud.gov:80/apps/section8/step2.cfm?state=MS,Mississippi',
#  'http://www.hud.gov:80/apps/section8/step2.cfm?state=MT,Montana',
#  'http://www.hud.gov:80/apps/section8/step2.cfm?state=NC,North+Carolina',
#  'http://www.hud.gov:80/apps/section8/step2.cfm?state=ND,North+Dakota',
#  'http://www.hud.gov:80/apps/section8/step2.cfm?state=NE,Nebraska',
#  'http://www.hud.gov:80/apps/section8/step2.cfm?state=NH,New+Hampshire',
#  'http://www.hud.gov:80/apps/section8/step2.cfm?state=NH,NewHampshire',
#  'http://www.hud.gov:80/apps/section8/step2.cfm?state=NJ,New+Jersey',
#  'http://www.hud.gov:80/apps/section8/step2.cfm?state=NM,New+Mexico',
#  'http://www.hud.gov:80/apps/section8/step2.cfm?state=NV,Nevada',
#  'http://www.hud.gov:80/apps/section8/step2.cfm?state=NY%2CNewyork',
#  'http://www.hud.gov:80/apps/section8/step2.cfm?state=NY,New+York',
#  'http://www.hud.gov:80/apps/section8/step2.cfm?state=OH,ohio',
#  'http://www.hud.gov:80/apps/section8/step2.cfm?state=OK,Oklahoma',
#  'http://www.hud.gov:80/apps/section8/step2.cfm?state=OR',
#  'http://www.hud.gov:80/apps/section8/step2.cfm?state=OR,Oregon',
#  'http://www.hud.gov:80/apps/section8/step2.cfm?state=PA,%20Pennsylvania',
#  'http://www.hud.gov:80/apps/section8/step2.cfm?state=PA,Pennsylvania',
#  'http://www.hud.gov:80/apps/section8/step2.cfm?state=PR,Puerto+Rico',
#  'http://www.hud.gov:80/apps/section8/step2.cfm?state=RI,Rhode+Island',
#  'http://www.hud.gov:80/apps/section8/step2.cfm?state=RI,RhodeIsland',
#  'http://www.hud.gov:80/apps/section8/step2.cfm?state=SC,South+Carolina',
#  'http://www.hud.gov:80/apps/section8/step2.cfm?state=SD,South+Dakota',
#  'http://www.hud.gov:80/apps/section8/step2.cfm?state=TN,Tennessee',
#  'http://www.hud.gov:80/apps/section8/step2.cfm?state=TX,Texas',
#  'http://www.hud.gov:80/apps/section8/step2.cfm?state=UT,Utah',
#  'http://www.hud.gov:80/apps/section8/step2.cfm?state=VA,Virginia',
#  'http://www.hud.gov:80/apps/section8/step2.cfm?state=VT,Vermont',
#  'http://www.hud.gov:80/apps/section8/step2.cfm?state=WA,Washington',
#  'http://www.hud.gov:80/apps/section8/step2.cfm?state=WI,Wisconsin',
#  'http://www.hud.gov:80/apps/section8/step2.cfm?state=WV,West+Virginia',
#  'http://www.hud.gov:80/apps/section8/step2.cfm?state=WY,Wyoming',
#  'http://www.hud.gov:80/arizona',
#  'http://www.hud.gov:80/arkansas',
#  'http://www.hud.gov:80/assist',
#  'http://www.hud.gov:80/assist/acrobat.cfm',
#  'http://www.hud.gov:80/assist/contactus.cfm',
#  'http://www.hud.gov:80/assist/contactus.cfm?&lang=en',
#  'http://www.hud.gov:80/assist/cookies.cfm',
#  'http://www.hud.gov:80/assist/index.cfm',
#  'http://www.hud.gov:80/assist/index.cfm?&lang=en',
#  'http://www.hud.gov:80/assist/privacy.cfm',
#  'http://www.hud.gov:80/assist/privacy.cfm?&lang=en',
#  'http://www.hud.gov:80/assist/service.cfm?&lang=en',
#  'http://www.hud.gov:80/assist/siteindex.cfm',
#  'http://www.hud.gov:80/assist/siteindex.cfm/top',
#  'http://www.hud.gov:80/assist/siteindex.cfm?&lang=en',
#  'http://www.hud.gov:80/assist/sitemap.cfm',
#  'http://www.hud.gov:80/basic.cfm',
#  'http://www.hud.gov:80/bdfy2000/summary/pdandr/randt.cfm',
#  'http://www.hud.gov:80/bfields.html',
#  'http://www.hud.gov:80/budget.html',
#  'http://www.hud.gov:80/budget01/justif/cpd/rc.cfm',
#  'http://www.hud.gov:80/buying/',
#  'http://www.hud.gov:80/buying/buyhudhm.cfm',
#  'http://www.hud.gov:80/buying/comq.cfm',
#  'http://www.hud.gov:80/buying/index.cfm',
#  'http://www.hud.gov:80/buying/index.cfm?&lang=en',
#  'http://www.hud.gov:80/buying/insured.cfm',
#  'http://www.hud.gov:80/buying/localbuying.cfm',
#  'http://www.hud.gov:80/buying/localbuying.cfm?&lang=en',
#  'http://www.hud.gov:80/buying/localbuying.cfm?lang=en',
#  'http://www.hud.gov:80/buying/localhomebuy.cfm',
#  'http://www.hud.gov:80/buying/localpredlend.cfm',
#  'http://www.hud.gov:80/buying/mortprog.cfm',
#  'http://www.hud.gov:80/buying/morttips.cfm',
#  'http://www.hud.gov:80/buying/refinance.cfm',
#  'http://www.hud.gov:80/buying/reverse.cfm',
#  'http://www.hud.gov:80/buying/rvrsmort.cfm',
#  'http://www.hud.gov:80/buying/terms_eng-sp.cfm',
#  'http://www.hud.gov:80/calculator',
#  'http://www.hud.gov:80/calendar/',
#  'http://www.hud.gov:80/calendar/index.cfm',
#  'http://www.hud.gov:80/cb/cbmainmn.html',
#  'http://www.hud.gov:80/cdbg',
#  'http://www.hud.gov:80/cfda/2001/14168.cfm',
#  'http://www.hud.gov:80/cfo/cfoacc96.html',
#  'http://www.hud.gov:80/cio/ciohome.html',
#  'http://www.hud.gov:80/cio/year2000',
#  'http://www.hud.gov:80/cn',
#  'http://www.hud.gov:80/codetalk',
#  'http://www.hud.gov:80/codtctrs.html',
#  'http://www.hud.gov:80/community/',
#  'http://www.hud.gov:80/community/index.cfm',
#  'http://www.hud.gov:80/community/index.cfm?&lang=en',
#  'http://www.hud.gov:80/community/orcomm.html',
#  'http://www.hud.gov:80/community/yourcommunity.cfm',
#  'http://www.hud.gov:80/complaints',
#  'http://www.hud.gov:80/complaints/badlandlord.cfm',
#  'http://www.hud.gov:80/complaints/custservice.cfm',
#  'http://www.hud.gov:80/complaints/decpcontract.cfm',
#  'http://www.hud.gov:80/complaints/fraud_waste.cfm',
#  'http://www.hud.gov:80/complaints/housediscrim.cfm',
#  'http://www.hud.gov:80/complaints/index.cfm',
#  'http://www.hud.gov:80/complaints/index.cfm?&lang=en',
#  'http://www.hud.gov:80/complaints/index.cfm?lang=en',
#  'http://www.hud.gov:80/complaints/landsales.cfm',
#  'http://www.hud.gov:80/complaints/manhousing.cfm',
#  'http://www.hud.gov:80/comq.html',
#  'http://www.hud.gov:80/consum.cfm',
#  'http://www.hud.gov:80/consumer/',
#  'http://www.hud.gov:80/consumer/index.cfm',
#  'http://www.hud.gov:80/consumer/index.cfm?&lang=en',
#  'http://www.hud.gov:80/consumer/local.cfm',
#  'http://www.hud.gov:80/content/releases',
#  'http://www.hud.gov:80/counseling/501',
#  'http://www.hud.gov:80/counselors',
#  'http://www.hud.gov:80/cpd/2020soft.html',
#  'http://www.hud.gov:80/cpd/c2020/mapgal.html',
#  'http://www.hud.gov:80/cpd/colonias.html',
#  'http://www.hud.gov:80/cpd/cpd/cpdprog.html',
#  'http://www.hud.gov:80/cpd/cpdenvir.html',
#  'http://www.hud.gov:80/cpd/cpdhome.html',
#  'http://www.hud.gov:80/cpd/cps/cpsqsas.html',
#  'http://www.hud.gov:80/cpd/econdev/ythhome.html',
#  'http://www.hud.gov:80/cpd/ezec/ceb.html',
#  'http://www.hud.gov:80/cpd/home/homefront/M2/M2T0-00.html',
#  'http://www.hud.gov:80/cpd/home/homeweb.html',
#  'http://www.hud.gov:80/cpd/home/pubindex/notices.html',
#  'http://www.hud.gov:80/cpd/hopwahom.html',
#  'http://www.hud.gov:80/cpd/idis/refman/ref_man_15.pdf',
#  'http://www.hud.gov:80/cpd/ocv/envregul.html',
#  'http://www.hud.gov:80/cpd/oed/funding.html',
#  'http://www.hud.gov:80/cpd/oed/programs.html',
#  'http://www.hud.gov:80/cpd/s+c.html',
#  'http://www.hud.gov:80/cpd/statecon.html',
#  'http://www.hud.gov:80/cr',
#  'http://www.hud.gov:80/crlocator',
#  'http://www.hud.gov:80/cts/osdbu.html',
#  'http://www.hud.gov:80/cuomo.cfm',
#  'http://www.hud.gov:80/datamap',
#  'http://www.hud.gov:80/december.html',
#  'http://www.hud.gov:80/developer',
#  'http://www.hud.gov:80/directory',
#  'http://www.hud.gov:80/directory/800/',
#  'http://www.hud.gov:80/directory/800/800num1.cfm',
#  'http://www.hud.gov:80/directory/800/800num2.cfm',
#  'http://www.hud.gov:80/directory/800/800num3.cfm',
#  'http://www.hud.gov:80/directory/800/800num4.cfm',
#  'http://www.hud.gov:80/directory/800/800num5.cfm',
#  'http://www.hud.gov:80/directory/800/800num6.cfm',
#  'http://www.hud.gov:80/directory/800/800num7.cfm',
#  'http://www.hud.gov:80/directory/800/800num8.cfm',
#  'http://www.hud.gov:80/directory/800/800num9.cfm',
#  'http://www.hud.gov:80/directory/800/index.cfm',
#  'http://www.hud.gov:80/directory/800/parainformacion.cfm',
#  'http://www.hud.gov:80/directory/ascdir3.cfm',
#  'http://www.hud.gov:80/directory/director.cfm',
#  'http://www.hud.gov:80/directory/dirodoc.cfm',
#  'http://www.hud.gov:80/directory/dirpdr.cfm',
#  'http://www.hud.gov:80/directory/dirpubaf.cfm',
#  'http://www.hud.gov:80/dirfbci.cfm',
#  'http://www.hud.gov:80/dirfpm.cfm',
#  'http://www.hud.gov:80/economicdevelopment/',
#  'http://www.hud.gov:80/economicdevelopment/index.cfm',
#  'http://www.hud.gov:80/economicdevelopment/index.cfm?&lang=en',
#  'http://www.hud.gov:80/emaps',
#  'http://www.hud.gov:80/emarc',
#  'http://www.hud.gov:80/energy/',
#  'http://www.hud.gov:80/esnaps/',
#  'http://www.hud.gov:80/exhibit300/',
#  'http://www.hud.gov:80/exhibit300/index.cfm',
#  'http://www.hud.gov:80/ezec/locator/',
#  'http://www.hud.gov:80/fairhousing',
#  'http://www.hud.gov:80/fairhousing%20',
#  'http://www.hud.gov:80/fairhousing%E2%80%8E',
#  'http://www.hud.gov:80/faqs/faqbuying.cfm',
#  'http://www.hud.gov:80/faqs/faqbuying.cfm?&lang=en',
#  'http://www.hud.gov:80/faqs/faqconsumer.cfm',
#  'http://www.hud.gov:80/faqs/faqforeclose.cfm',
#  'http://www.hud.gov:80/faqs/faqhomebuy.cfm',
#  'http://www.hud.gov:80/faqs/faqrenting.cfm',
#  'http://www.hud.gov:80/fathersday',
#  'http://www.hud.gov:80/fathersday2012',
#  'http://www.hud.gov:80/fedcolni.html',
#  'http://www.hud.gov:80/fha/choosefha.cfm',
#  'http://www.hud.gov:80/fha/comp/refunds/fharefun.html',
#  'http://www.hud.gov:80/fha/comp/refunds/page1.html',
#  'http://www.hud.gov:80/fha/sfh/203k/203kabou.html',
#  'http://www.hud.gov:80/fha/sfh/203k/203kmenu.html',
#  'http://www.hud.gov:80/fha/sfh/203k/sfhreha2.html',
#  'http://www.hud.gov:80/fha/sfh/203k/sfhrehab.html',
#  'http://www.hud.gov:80/fha/sfh/203kmenu.html',
#  'http://www.hud.gov:80/fha/sfh/buying/buyhm.html',
#  'http://www.hud.gov:80/fha/sfh/buying/glossary.html',
#  'http://www.hud.gov:80/fha/sfh/buying/protect.html',
#  'http://www.hud.gov:80/fha/sfh/mps/mpshome.html',
#  'http://www.hud.gov:80/fha/sfh/res/resborwr.html',
#  'http://www.hud.gov:80/fha/sfh/res/respa_hm.html',
#  'http://www.hud.gov:80/fha/sfh/res/respamor.html',
#  'http://www.hud.gov:80/fha/sfh/res/sfhrestc.html',
#  'http://www.hud.gov:80/fha/sfh/sf_home.html',
#  'http://www.hud.gov:80/fha/sfh/talk/addr_den.html',
#  'http://www.hud.gov:80/fhaloansales',
#  'http://www.hud.gov:80/fhe/504/504complaint.html',
#  'http://www.hud.gov:80/fhe/504/sect504rights.html',
#  'http://www.hud.gov:80/fhe/fhehous.html',
#  'http://www.hud.gov:80/fhe/fheo.html.',
#  'http://www.hud.gov:80/fhe/modelcodes',
#  'http://www.hud.gov:80/fhe/sec3over.html',
#  'http://www.hud.gov:80/fheo.cfm',
#  'http://www.hud.gov:80/fheo.html',
#  'http://www.hud.gov:80/fheopredatorylending',
#  'http://www.hud.gov:80/finanbf.cfm',
#  'http://www.hud.gov:80/florida',
#  'http://www.hud.gov:80/foreclosure',
#  'http://www.hud.gov:80/foreclosure/faqs.cfm',
#  'http://www.hud.gov:80/foreclosure/fctimeline.cfm',
#  'http://www.hud.gov:80/foreclosure/foreclosureprocess.cfm',
#  'http://www.hud.gov:80/foreclosure/foreclosuretips.cfm',
#  'http://www.hud.gov:80/foreclosure/index.cfm',
#  'http://www.hud.gov:80/foreclosure/index.cfm?&lang=en',
#  'http://www.hud.gov:80/foreclosure/index.cfm?p=Homepath&s=Resources&t=HUD--Tips+for+Avoiding+Foreclosure',
#  'http://www.hud.gov:80/foreclosure/local.cfm',
#  'http://www.hud.gov:80/foreclosure/redemption.cfm',
#  'http://www.hud.gov:80/foreclosure/relocation.cfm',
#  'http://www.hud.gov:80/foreclosure/workingwithlenders.cfm',
#  'http://www.hud.gov:80/forms',
#  'http://www.hud.gov:80/funds/',
#  'http://www.hud.gov:80/funds/healthcarefacility.cfm',
#  'http://www.hud.gov:80/funds/index.cfm',
#  'http://www.hud.gov:80/funds/index.cfm?&lang=en',
#  'http://www.hud.gov:80/funds/singlefamily.cfm',
#  'http://www.hud.gov:80/fy2013budget',
#  'http://www.hud.gov:80/fy2014budget',
#  'http://www.hud.gov:80/georgia',
#  'http://www.hud.gov:80/goodneighbor',
#  'http://www.hud.gov:80/goodneighbor/dollarhomes/dhmabout.html',
#  'http://www.hud.gov:80/goodneighbor/nonprofitsales/index.html',
#  'http://www.hud.gov:80/grants/',
#  'http://www.hud.gov:80/grants/index.cfm',
#  'http://www.hud.gov:80/grants/index.cfm?&lang=en',
#  'http://www.hud.gov:80/groups/',
#  'http://www.hud.gov:80/groups/appraisers.cfm',
#  'http://www.hud.gov:80/groups/appraisers.cfm?&lang=en',
#  'http://www.hud.gov:80/groups/appraisers.cfm?lang=en',
#  'http://www.hud.gov:80/groups/brokers.cfm',
#  'http://www.hud.gov:80/groups/brokers.cfm?&lang=en',
#  'http://www.hud.gov:80/groups/disabilities.cfm',
#  'http://www.hud.gov:80/groups/disabilities.cfm?&lang=en',
#  'http://www.hud.gov:80/groups/fairhousing.cfm',
#  'http://www.hud.gov:80/groups/fairhousing.cfm?&lang=en',
#  'http://www.hud.gov:80/groups/grantees.cfm',
#  'http://www.hud.gov:80/groups/grantees.cfm?&lang=en',
#  'http://www.hud.gov:80/groups/healthcare.cfm',
#  'http://www.hud.gov:80/groups/investors.cfm?&lang=en',
#  'http://www.hud.gov:80/groups/landlords.cfm',
#  'http://www.hud.gov:80/groups/landlords.cfm?&lang=en',
#  'http://www.hud.gov:80/groups/legal.cfm',
#  'http://www.hud.gov:80/groups/lenders.cfm',
#  'http://www.hud.gov:80/groups/lenders.cfm?&lang=en',
#  'http://www.hud.gov:80/groups/localhomerepair.cfm',
#  'http://www.hud.gov:80/groups/multifamily.cfm',
#  'http://www.hud.gov:80/groups/multifamily.cfm?&lang=en',
#  'http://www.hud.gov:80/groups/nativeamericans.cfm',
#  'http://www.hud.gov:80/groups/nativeamericans.cfm/?&lang=en',
#  'http://www.hud.gov:80/groups/officials.cfm?&lang=en',
#  'http://www.hud.gov:80/groups/phastribes.cfm',
#  'http://www.hud.gov:80/groups/phastribes.cfm?&lang=en',
#  'http://www.hud.gov:80/groups/seniors.cfm',
#  'http://www.hud.gov:80/groups/seniors.cfm?&lang=en',
#  'http://www.hud.gov:80/groups/smallbusiness.cfm',
#  'http://www.hud.gov:80/groups/students.cfm',
#  'http://www.hud.gov:80/groups/students.cfm?&lang=en',
#  'http://www.hud.gov:80/groups/tenants.cfm',
#  'http://www.hud.gov:80/groups/tenants.cfm?&lang=en',
#  'http://www.hud.gov:80/gse',
#  'http://www.hud.gov:80/hawaii',
#  'http://www.hud.gov:80/hdiscrim.html',
#  'http://www.hud.gov:80/healthcare',
#  'http://www.hud.gov:80/healthy/index.cfm',
#  'http://www.hud.gov:80/healthy/mainmenu.html',
#  'http://www.hud.gov:80/healthy/safehome.html',
#  'http://www.hud.gov:80/healthyhomes',
#  'http://www.hud.gov:80/hhchild.html',
#  'http://www.hud.gov:80/hoc/sna/snanfpap.html',
#  'http://www.hud.gov:80/hoc/sna/snatftht.html',
#  'http://www.hud.gov:80/homeless',
#  'http://www.hud.gov:80/homeless/definition.cfm',
#  'http://www.hud.gov:80/homeless/fedprog.cfm',
#  'http://www.hud.gov:80/homeless/hmasist1.cfm',
#  'http://www.hud.gov:80/homeless/hmlsagen.cfm',
#  'http://www.hud.gov:80/homeless/index.cfm',
#  'http://www.hud.gov:80/homeless/index.cfm?&lang=en',
#  'http://www.hud.gov:80/homeless/index.cfm?lang=en',
#  'http://www.hud.gov:80/homelesscount',
#  'http://www.hud.gov:80/homeownership',
#  'http://www.hud.gov:80/homeprogram/',
#  'http://www.hud.gov:80/homes/',
#  'http://www.hud.gov:80/homes/building.cfm',
#  'http://www.hud.gov:80/homes/homesforsale.cfm',
#  'http://www.hud.gov:80/homes/homesforsale.cfm?&lang=en',
#  'http://www.hud.gov:80/homes/index.cfm',
#  'http://www.hud.gov:80/homes/index.cfm?&lang=en',
#  'http://www.hud.gov:80/homes/manufactured.cfm',
#  'http://www.hud.gov:80/hopeforhomeowners/',
#  'http://www.hud.gov:80/hopeforhomeowners/consumerfactsheet.cfm',
#  'http://www.hud.gov:80/hopeforhomeowners/index.cfm',
#  'http://www.hud.gov:80/housingcounseling',
#  'http://www.hud.gov:80/hudclips',
#  'http://www.hud.gov:80/hudvet/',
#  'http://www.hud.gov:80/idaho',
#  'http://www2.hud.gov:80/cdc.html',
#  'http://www2.hud.gov:80/enforce/ecindex.html',
#  'http://www2.hud.gov:80/gpra/gnma.html',
#  'http://www2.hud.gov:80/gpra/ogc.html',
#  'https://www.hud.gov/emarc/index.cfm?fuseaction=emar.registrationNotOpenError&eventid=1177',
#  'https://www11.hud.gov/HUD_Systems',
#  'https://www11.hud.gov/HUD_Systems/index.cfm',
#  'https://www21.hud.gov/idis',
#  'https://www5.hud.gov/Ecomplaints',
#  'https://www5.hud.gov/Ecomplaints/Logins/PagLogin.jsp',
#  'https://www5.hud.gov/ecpcis',
#  'https://www5.hud.gov/ecpcis/index.jsp',
#  'https://www5.hud.gov/Ecpcis/main/ECPCIS_List',
#  'https://www5.hud.gov/ecpcis/main/ECPCIS_List.jsp',
#  'https://www5.hud.gov/Ecpcis/main/ECPCIS_List/index.jsp',
#  'https://www5.hud.gov/Ecpcis/main/ECPCIS_List/main/ECPCIS_List.jsp',
#  'https://www5.hud.gov/Ecpcis/main/ECPCIS_List/main/Help.html',
#  'https://www5.hud.gov/ecpcis/main/Help.html',
#  'https://www5.hud.gov/FHALender/',
#  'https://www5.hud.gov/FHALender/fhalogin.jsp',
#  'https://www5.hud.gov/FHALender/FHAStore',
#  'https://www5.hud.gov/FHALender/FHAUploadServlet',
#  'https://www5.hud.gov/FHALender/Online/page_address.jsp',
#  'https://www5.hud.gov/FHALender/Online/page_address.jsp?edit=1',
#  'https://www5.hud.gov/FHALender/Online/page_already_registered_question.jsp',
#  'https://www5.hud.gov/FHALender/Online/page_certification.jsp',
#  'https://www5.hud.gov/FHALender/Online/page_contacts.jsp',
#  'https://www5.hud.gov/FHALender/Online/page_contacts.jsp?edit=1',
#  'https://www5.hud.gov/FHALender/Online/page_conversion.jsp',
#  'https://www5.hud.gov/FHALender/Online/page_conversion.jsp?edit=1',
#  'https://www5.hud.gov/FHALender/Online/page_conversion_upload.jsp',
#  'https://www5.hud.gov/FHALender/Online/page_general_info.jsp',
#  'https://www5.hud.gov/FHALender/Online/page_general_info.jsp?edit=1',
#  'https://www5.hud.gov/FHALender/Online/page_history_business_status.jsp',
#  'https://www5.hud.gov/FHALender/Online/page_history_business_status.jsp?edit=1',
#  'https://www5.hud.gov/FHALender/Online/page_individual.jsp',
#  'https://www5.hud.gov/FHALender/Online/page_individual.jsp?edit=1',
#  'https://www5.hud.gov/FHALender/Online/page_initial_type.jsp',
#  'https://www5.hud.gov/FHALender/Online/page_items_to_submit.jsp',
#  'https://www5.hud.gov/FHALender/Online/page_items_to_submit.jsp?edit=1',
#  'https://www5.hud.gov/FHALender/Online/page_login.jsp',
#  'https://www5.hud.gov/FHALender/Online/page_logout.jsp',
#  'https://www5.hud.gov/FHALender/Online/page_new_upload.jsp',
#  'https://www5.hud.gov/FHALender/Online/page_new_upload.jsp?edit=1',
#  'https://www5.hud.gov/FHALender/Online/page_officers.jsp',
#  'https://www5.hud.gov/FHALender/Online/page_payment_initial.jsp',
#  'https://www5.hud.gov/FHALender/Online/page_signature.jsp',
#  'https://www5.hud.gov/FHALender/Online/page_summary.jsp',
#  'https://www5.hud.gov/FHALender/Online/page_summary_conversion.jsp',
#  'https://www5.hud.gov/Hud903/main/pagHUD903Form.jsp']

# %%
with open('inputs/links_hud.csv', 'w') as f:
    writer = csv.writer(f)
    for line in hud_links:
        writer.writerow([line])

# %%
terms = one_word_terms + two_word_terms
control_terms = ['heterosexual', 'straight']
dates_pre = [2013, 1, 20, 2017, 1, 19]
dates_post = [2017, 1, 20, 2019, 8, 22]
output_name = 'counts_hud'
gc.get_output('inputs/links_hud.csv', output_name, terms, dates_pre, dates_post, store_text=True)
# Out:
# HBox(children=(IntProgress(value=0, description='progress: ', max=567, style=ProgressStyle(description_width='…

# %%
multi_word_terms = two_word_terms[:]
df_pre_merged, df_post_merged, col_names = a.get_final_df(None, multi_word_terms, one_word_terms, output_name)
inconsistencies = []
df_pre_merged = df_pre_merged[~df_pre_merged.id.isin(inconsistencies)]
df_post_merged = df_post_merged[~df_post_merged.id.isin(inconsistencies)]
rel_changes, rel_pre, rel_post = a.get_changes(df_pre_merged, df_post_merged, 'id', col_names, 'ttal', pctg=True)
abs_changes = a.get_changes(df_pre_merged, df_post_merged, 'id', col_names, 'ttal', pctg=False)
# uncomment to check relative frequencies
#rel_pre.sort_values()
#rel_post.sort_values()
# Out:
# The relative number of terms changed -100.00 %, from 0.001 to 0.000
# The absolute number of terms changed -100.00 %, from 1 to 0

# %%
a.display_side_by_side(rel_changes, abs_changes)
# Out:
# <table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>term</th>
#       <th>change</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>sex</td>
#       <td>-100.00</td>
#     </tr>
#   </tbody>
# </table style="display:inline"><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>term</th>
#       <th>change</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>sex</td>
#       <td>-1.00</td>
#     </tr>
#   </tbody>
# </table style="display:inline">
